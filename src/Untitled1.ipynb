# %%
import pandas as pd

# %%
df = pd.read_pickle('../aws_folder/cust_table_out.pkl')

# %%
df.groupby('cluster').count()
# Out:
#          qty_shrink_per_day  shrink_value_per_day  POP2010  FD_ratio  \
# cluster
# 0                      4646                  4646     4646      4646
# 1                      4821                  4821     4821      4821
# 2                      1564                  1564     1564      1564
# 3                       767                   767      767       767
#
#          unemp_rate  dens_sq_mile  street  city  state  zip_code  \
# cluster
# 0              4646          4646    4646  4646   4646      4646
# 1              4821          4821    4821  4821   4821      4821
# 2              1564          1564    1564  1564   1564      1564
# 3               767           767     767   767    767       767
#
#          avg_UPC_per_visit  days_between_visits  last_visit
# cluster
# 0                     4646                 4646        4646
# 1                     4821                 4821        4821
# 2                     1564                 1564        1564
# ...

# %% [markdown]
# [image '../images/aws_best_params.png']
