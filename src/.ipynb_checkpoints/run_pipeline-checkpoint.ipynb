# %%
import pandas as pd
from data_clean import DataClean
from add_public_data import PublicData
from create_lag import CreateLag
from cust_seg import CustSeg
from split import Split
from std_scale import StdScale
from pred_model import PredModel
from forcast import Forcast
from sklearn.neural_network import MLPRegressor
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from matplotlib import rc
from model_functions import plot_rmse, model_clusters

# %%
# %matplotlib inline
pd.set_option('max_columns',500)
font = {'size': 20}
rc('font', **font)
plt.style.use('seaborn-bright')

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
df = pd.read_pickle('../data/archive/raw_data.pkl')

# %%
df_info = df[['address1', 'address2', 'city', 'state', 'postal_code']]

# %%
df_filt = pd.DataFrame()
i = 0
for add in df_info.address1.unique():
    mask = df_info.address1 == add
    for index, row in df_info[ mask ].iterrows():
        df_filt.set_value(i, 'address1', row[0])
        df_filt.set_value(i, 'street', row[1])
        df_filt.set_value(i, 'city', row[2])
        df_filt.set_value(i, 'state', row[3])
        df_filt.set_value(i, 'zip_code', row[4])
        i += 1
        break
# Out:
# /home/luke/anaconda2/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# /home/luke/anaconda2/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   import sys
# /home/luke/anaconda2/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# /home/luke/anaconda2/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:9: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if __name__ == '__main__':
# /home/luke/anaconda2/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.

# %%
df_filt.to_pickle('../data/SRP/custs_by_address.pkl')

# %%
df_filt.head()
# Out:
#             address1              street          city state    zip_code
# 0     SPEEDWAY #6989  10920 CREEDMOOR RD       RALEIGH    NC       27615
# 1     SPEEDWAY #8223    520 MAIN ST WEST       AHOSKIE    NC  27910-3324
# 2     SPEEDWAY #8224       604 E MAIN ST  MURFREESBORO    NC  27855-1333
# 3  SHEETZ - DSD #307     11449 KINGS HWY   KING GEORGE    VA       22485
# 4  SHEETZ - DSD #151      1 W 4TH STREET      EMPORIUM    PA  15834-1215

# %%
# middle 1
dc = DataClean(remove_nan_rows=True)
df_clean = dc.fit_transform(df)

# %%
# middle 2
pub = PublicData(include_crime=False, remove_nan_rows=True)
df_public_cust = pub.fit_transform(df_clean)

# %%
# left 1
cl_cat = CreateLag(lag_periods=2, col_filters=['address1', 'item_category'], 
                   date_col='visit_date', lag_vars=['qty_shrink_per_day', 'shrink_value_per_day'], 
                   col_name_suf='_by_cat', remove_nan_rows=True)
df_lag_cat = cl_cat.fit_transform(df_clean)

# %%
# middle 3
cs = CustSeg(clusters=4)
cust_table = cs.fit_transform(df_public_cust)
cust_table.groupby('cluster').mean()
# Out:
# /home/luke/Dropbox/Galvanize/DSI/Capstone/Mashey/src/cust_seg.py:78: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   self.cust_table.set_value(index, 'zip_code', zip_code)
# /home/luke/Dropbox/Galvanize/DSI/Capstone/Mashey/src/cust_seg.py:79: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   self.cust_table.set_value(index, 'customer_id', cust_id)
# /home/luke/Dropbox/Galvanize/DSI/Capstone/Mashey/src/cust_seg.py:80: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   break
# /home/luke/Dropbox/Galvanize/DSI/Capstone/Mashey/src/cust_seg.py:81: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# /home/luke/Dropbox/Galvanize/DSI/Capstone/Mashey/src/cust_seg.py:82: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   self._add_cols()
#          qty_shrink_per_day  shrink_value_per_day       POP2010  FD_ratio  \
# cluster
# 0                  0.019959              0.105711  1.136727e+06  0.144409
# 1                  0.016650              0.091053  7.905963e+06  0.061355
# 2                  0.284115              1.286692  5.917412e+05  0.229385
# 3                  0.013028              0.083738  5.510364e+05  0.314993
#
#          unemp_rate  dens_sq_mile  avg_UPC_per_visit  days_between_visits
# cluster
# 0          0.087166   3727.555215           1.092452            23.542829
# 1          0.081524  17650.238189           1.084379            10.994382
# 2          0.088868   1966.402452           1.104132            31.330399
# 3          0.074373   1770.396867           1.103867            25.874331

# %%
f = open("cities.txt","w+")
for cust in cust_table[['street', 'zip_code', 'cluster']].values:
    cust = list(cust)
    clust = cust.pop()
    if clust == '0':
        f.write('{} {} <default-dot>'.format(cust[0], cust[1]))
    elif clust == '1':
        f.write('{} {} <blue-dot>'.format(cust[0], cust[1]))
    elif clust == '2':
        f.write('{} {} <green-dot>'.format(cust[0], cust[1]))
    elif clust == '3':
        f.write('{} {} <violet-dot>'.format(cust[0], cust[1]))
    f.write('\n')
f.close()

# %%
import pandas as pd
import os
from geopy import geocoders
from geopy.geocoders import GoogleV3

API_KEY = os.getenv("API1234")
g = GoogleV3(api_key=API_KEY)

street_i = df_filt.columns.get_loc('state')
city_i = df_filt.columns.get_loc('city')
state_i = df_filt.columns.get_loc('state')
zip_i = df_filt.columns.get_loc('zip_code')

for index, row in df_filt.iterrows():
    street = row[street_i]
    city = row[city_i]
    state = row[state_i]
    zip_code = row[zip_i]
    address = '{} {}, {}, {}'.format(street, city, state, zip_code)
    try:
        loc = g.geocode(address, timeout=15)
        df_filt.set_value(index, 'latitude', loc.latitude)
        df_filt.set_value(index, 'longitude', loc.longitude)
    except Exception as e:
        print('Error, skipping address...', e)
# Out:
# 45.6762725
# /home/luke/anaconda2/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:26: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /home/luke/anaconda2/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:27: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# 45.5295528
# 45.5295528
# 45.5517361
# 45.5539123
# 45.4053517
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# 45.5179745
# 45.5179745
# 45.4923824
# 45.4395124
# 45.4395124
# 45.5113506
# 45.5113506
# 45.5352835
# 45.5517361
# 45.5392862
# 45.5143706
# 45.4863921
# 45.4863921
# 45.413914
# 45.3611308
# 45.3001178
# 45.21011619999999
# 44.9046074
# 44.0431493
# 44.0350489
# 45.59087340000001
# 48.0563616
# 47.9990269
# 47.837259
# 47.8419525
# 47.7933719
# 47.8369467
# 47.7612471
# 47.91287560000001
# 47.759038
# 47.7542651
# 47.6701193
# 47.6688298
# 47.6150436
# 47.55770769999999
# 47.5301011
# 47.5301011
# 47.6478787
# 47.4886652
# 47.4623372
# 47.4116866
# 47.39648829999999
# 47.3165043
# 47.3394747
# 47.1971241
# 47.2254542
# 47.2649829
# 47.2019421
# 47.1547274
# 47.2147081
# 47.10795479999999
# 47.1616994
# 47.8553772
# 33.76353539999999
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# 33.6160293
# 33.5725815
# 33.4366655
# 33.5725815
# 33.3345698
# 33.4366655
# 33.3345698
# 28.5416658
# 28.6092911
# 28.5085825
# 28.5542151
# 28.6678749
# 28.0894599
# 29.2046542
# 29.2046542
# 28.0600145
# 27.926156
# 27.7286699
# 27.791959
# 27.7480089
# 27.4872771
# 27.3346138
# 27.3430762
# 26.132433
# 28.0307138
# 28.0563834
# 26.6654996
# 27.6018976
# 26.5254562
# 26.1242719
# 26.0181766
# 26.0517448
# 26.2778269
# 33.027733
# 34.145515
# 32.67942
# 41.9236507
# 40.7179622
# 32.715738
# 32.97602940000001
# 36.266572
# 35.952556
# 42.25319959999999
# 33.1799688
# 32.9259646
# 32.9355008
# 33.1799688
# 33.8291867
# 42.7405578
# 39.0533891
# 42.6585338
# 41.8819283
# 41.8925085
# 41.89136999999999
# 41.8725524
# 41.993029
# 41.9153781
# 41.8132909
# 41.6091129
# 41.89332539999999
# 41.7205889
# 42.1275267
# 41.75798959999999
# 41.6784627
# 41.7205889
# 41.5318621
# 41.5132913
# 41.9202827
# 42.1674607
# 41.6091129
# 41.8733696
# 42.19696889999999
# 41.9752644
# 41.9889173
# 41.8778243
# 41.7962928
# 41.8929153
# 41.95450049999999
# 41.794402
# 42.0290522
# 41.9663562
# 42.1099506
# 41.8725524
# 41.4959577
# 41.9003099
# 42.23404559999999
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# 41.9920835
# 41.8839927
# 41.4959577
# 41.9202827
# 41.8733696
# 41.904735
# 41.8725524
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# 42.2128686
# 41.8778243
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# 41.9236507
# 32.717251
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# 42.060011
# 32.8601513
# 26.5321109
# 40.6618507
# 40.626106
# 40.9215101
# 40.5623204
# 40.5934061
# 40.4960215
# 40.4960215
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# 33.1158665
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# 36.0633189
# 25.9428707
# 33.8822393
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# 33.1658698
# 32.9682679
# 33.8640647
# 37.6284406
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# 40.7181416
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# 32.737615
# 39.4626087
# 39.892517
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# ...
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.
# Error, skipping address... The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time.

# %%
# Out:
# 8

# %%
cust_table[['street', 'zip_code', 'cluster']].values[:60]
# Out:
# array([['404 NE 78TH ST', '98665', '3'],
#        ['15 NE BROADWAY ST', '97232', '2'],
#        ['519 NE BROADWAY ST', '97232', '2'],
#        ['10131 NE SANDY BLVD', '97220', '2'],
#        ['20800 NE SANDY BLVD', '97024', '0'],
#        ['1275 SE TUALATIN VALLEY HWY', '97123', '2'],
#        ['6950 NE CORNELL RD', '97124', '2'],
#        ['2355 NW TOWN CENTER DR', '97006', '0'],
#        ['1220 NW WATERHOUSE AVE', '97006', '0'],
#        ['12805 NW CORNELL RD', '97005', '0'],
#        ['8725 SW HALL BLVD', '97223', '0'],
#        ['11834 SW PACIFIC HWY', '97223', '0'],
#        ['621 SSE GRAND AVE', '97214', '0'],
#        ['3840 SE STARK ST', '97214', '2'],
#        ['5820 NE GLISAN ST', '97213', '0'],
#        ['515 NE 82ND AVE', '97220', '2'],
#        ['25737 SE STARK ST', '97060', '0'],
#        ['2450 SE 122ND AVE', '97233', '0'],
#        ['9215 SE POWELL BLVD', '97266', '0'],
#        ['10725 SE 82ND AVE', '97266', '0'],
#        ['14951 BANGY LANE', '97035', '0'],
#        ['7090 SW NYBERG RD', '97062', '0'],
#        ['204 HIGHWAY 99 W', '97132', '0'],
#        ['2005 HIGHWAY 99 W', '97128', '0'],
#        ['4397 COMMERCIAL ST SE', '97302', '0'],
#        ['6085 W 11TH AVE', '97402', '0'],
#        ['3640 GLENWOOD DR', '97403', '0'],
#        ['7433 N INTERSTATE AVE', '97217', '0'],
#        ['1209 4TH ST', '98270', '3'],
#        ['2631 WALNUT ST', '98201', '0'],
#        ['3432 132ND ST SW', '98012', '3'],
#        ['1331 164TH ST SW', '98037', '0'],
#        ['6602 220TH ST SW', '98043', '3'],
#        ['22000 HIGHWAY 99', '98026', '3'],
#        ['1505 NE 205TH ST', '98155', '0'],
#        ['1221 AVE D', '98290', '2'],
#        ['11700 NE 160TH', '98011', '0'],
#        ['15606 NE WOODINVILLE DUVALL PL', '98072', '0'],
#        ['11520 AVONDALE RD NE', '98052', '0'],
#        ['10801 NE 68TH', '98033', '0'],
#        ['12001 NE 8TH ST', '98005', '2'],
#        ['3670 150TH AVE SE', '98006', '0'],
#        ['1605 NW GILMAN BLVD', '98027', '0'],
#        ['15 E SUNSET WAY', '98027', '0'],
#        ['4333 TOLT AVE (SR 203)', '98014', '0'],
#        ['13138 INTERURBAN AVE S', '98168', '0'],
#        ['17941 108TH AVE SE', '98055', '0'],
#        ['22588 84TH AVE S', '98032', '2'],
#        ['1720 S 272ND ST', '98198', '0'],
#        ['1520 S 348TH ST', '98003', '0'],
#        ['902 SUPERMALL WAY', '98001', '0'],
#        ['2325 MERIDIAN AVE E', '98371', '3'],
#        ['3740 PACIFIC AVE', '98418', '3'],
#        ['801 DIVISION AVE', '98403', '3'],
#        ['5407 TACOMA MALL BLVD', '98409', '3'],
#        ['10716 PACIFIC AVE S', '98444', '3'],
#        ['6601 166TH AVE E', '98390', '2'],
#        ['16002 MERIDIAN AVE E', '98375', '3'],
#        ['6101 STEILACOOM BLVD', '98499', '3'],
#        ['13885 FRYELANDS BLVD', '98272', '3']], dtype=object)

# %%
# right 1
cl_store = CreateLag(lag_periods=2, col_filters=['address1'], 
                   date_col='visit_date', lag_vars=['qty_shrink_per_day', 'shrink_value_per_day'], 
                   col_name_suf='_by_store', remove_nan_rows=True)
df_lag_store = cl_store.fit_transform(df_clean)

# %% [markdown]
# ### Public for Lag

# %%
# left 2
df_public_cat = pub.fit_transform(df_lag_cat)

# %%
# right 2
df_public_store = pub.fit_transform(df_lag_store)

# %% [markdown]
# ### Split

# %%
non_feature_cols = ['shrink_value', 'shrink_to_sales_value_pct', 'shrink_value_out', 'shrink_to_sales_value_pct_out',
               'shrink_value_ex_del', 'shrink_to_sales_value_pct_ex_del', 'qty_inv_out', 'qty_shrink',
               'qty_shrink_ex_del', 'qty_shrink_out', 'qty_end_inventory', 'qty_f', 'qty_out', 'qty_ex_del',
               'qty_n', 'qty_delivery', 'qty_o', 'qty_d', 'qty_shrink_per_day', 'shrink_value_per_day']

# %%
# left 3
spl_cat = Split(non_feature_cols, target_col='shrink_value_per_day', split_by_time=False)
spl_cat.fit(df_public_cat, cust_table)
X, y, X_train_cat, X_test_cat, y_train_cat, y_test_cat \
= spl_cat.transform(df_public_cat, cust_table)

# %%
# right 3
split_date = pd.to_datetime('12/15/2017')
spl_store = Split(non_feature_cols, target_col='shrink_value_per_day', split_by_time=True, date_col='visit_date', split_date=split_date)
spl_store.fit(df_public_store, cust_table)
X, y, X_train_store, X_test_store, y_train_store, y_test_store \
= spl_store.transform(df_public_store, cust_table)

# %% [markdown]
# ### Std and Scale

# %%
ss = StdScale(std=True, scale=True)

# %%
# left 4
X_train_cat_ss = ss.fit_transform(X_train_cat)
X_test_cat_ss = ss.fit_transform(X_test_cat)

# %%
# right 4
X_ss = ss.fit_transform(X)
X_train_store_ss = ss.fit_transform(X_train_store)
X_test_store_ss = ss.fit_transform(X_test_store)

# %% [markdown]
# ### Test Models

# %%
# left 
cluster_rmse, naive_rmse, cluster_models = model_clusters(mlp_list, X_train, X_test, X_test_ns, 'shrink_value_per_day_lag1_by_cat', model_mask_cols, y_train, y_test)
plot_rmse(cluster_rmse, naive_rmse, num_clusters=len(X_train.cluster.unique()), 
          title='Predicting Next Visit Shrink Value')

# %% [markdown]
# ### Model

# %%
model = MLPRegressor()
params = {'hidden_layer_sizes': [(300,), (100,), (50,50), (50,50,50)], 'learning_rate_init': [0.01, 0.001, 0.0001], 
          'activation': ['identity', 'logistic', 'tanh', 'relu'], 'solver': ['adam'],  'max_iter': [200]}
params_basic = {'hidden_layer_sizes': [(10)], 'learning_rate_init': [0.01], 
          'activation': ['relu'], 'solver': ['adam'],  'max_iter': [10]}

# %%
# left 5
pm = PredModel(model, params_basic)
pm.fit(X_train_cat_ss, y_train_cat)
# Out:
# cluster:  1
#
# cluster:  2
#
# cluster:  3
#
# cluster:  4

# %%
# left 5 (continued)
preds = pm.predict(X_test_cat_ss)
preds[:10]
# Out:
# [0.4347946323926315,
#  -0.15047502849132935,
#  -0.40071836693012924,
#  0.34731468983189745,
#  -0.49726221850990854,
#  0.28328703334103583,
#  0.3697896535512033,
#  -0.30552759204381674,
#  -0.011366087424604933,
#  1.3767777002418975]

# %%
# right 5
forc_cols = ['FD_ratio', 'LAPOP1_10', 'POP2010', 'dens_sq_mile', 'unemp_rate', 'qty_POG_limit', 'unit_price', 
             'shrink_value_per_day_lag1_by_store', 'shrink_value_per_day_lag2_by_store' ]
for col in X_ss.columns:
    if 'customer_id' in col:
        forc_cols.append(col)
fc = Forcast(model, params_basic, forc_cols, num_periods=4)
fc.fit(X_ss, y)
# Out:
# cluster:  1
#
# cluster:  2
#
# cluster:  3
#
# cluster:  4

# %%
# right 5 (continued)
forc_cust_table = fc.forcast(cust_table)
forc_cust_table.head()
# Out:
#                       qty_shrink_per_day  shrink_value_per_day   POP2010  \
# address1
# #501 PACWEST/JACKSON           -0.043478             -0.398696  425363.0
# #505 PACWEST/JACKSON            0.200000              2.158000  735334.0
# #506 PACWEST/JACKSON            0.198864              2.326761  735334.0
# #508 PACWEST/JACKSON            0.312302              1.569603  735334.0
# #509 PACWEST/JACKSON            0.000000              0.000000  735334.0
#
#                       FD_ratio  unemp_rate  dens_sq_mile       city state  \
# address1
# #501 PACWEST/JACKSON  0.228642        0.08   2995.890411  VANCOUVER    WA
# #505 PACWEST/JACKSON  0.096296        0.06   6111.880661   PORTLAND    OR
# #506 PACWEST/JACKSON  0.096296        0.06   6111.880661   PORTLAND    OR
# #508 PACWEST/JACKSON  0.096296        0.09   3965.349290   PORTLAND    OR
# #509 PACWEST/JACKSON  0.096296        0.08   2925.449871   FAIRVIEW    OR
#
#                      zip_code customer_id  avg_UPC_per_visit  \
# address1
# #501 PACWEST/JACKSON    98665     3088198                1.0
# #505 PACWEST/JACKSON    97232     3088198                1.0
# #506 PACWEST/JACKSON    97232     3088198                1.0
# #508 PACWEST/JACKSON    97220     3088198                1.0
# #509 PACWEST/JACKSON    97024     3088198                1.0
#
#                       days_between_visits last_visit cluster  \
# address1
# #501 PACWEST/JACKSON             0.000000 2017-07-13       0
# #505 PACWEST/JACKSON             0.000000 2017-11-22       2
# #506 PACWEST/JACKSON            26.000000 2017-12-14       2
# #508 PACWEST/JACKSON            44.333333 2017-12-14       2
# #509 PACWEST/JACKSON             0.000000 2017-09-28       0
#
#                       period1_forc_shrink_value_per_day_per_item  \
# address1
# #501 PACWEST/JACKSON                                         NaN
# #505 PACWEST/JACKSON                                         NaN
# #506 PACWEST/JACKSON                               239290.865088
# #508 PACWEST/JACKSON                               239289.740177
# #509 PACWEST/JACKSON                                         NaN
#
#                               period1_pred_date  \
# address1
# #501 PACWEST/JACKSON                        NaT
# #505 PACWEST/JACKSON                        NaT
# #506 PACWEST/JACKSON 2018-01-09 00:00:00.000000
# #508 PACWEST/JACKSON 2018-01-27 07:59:59.971200
# #509 PACWEST/JACKSON                        NaT
#
#                       period2_forc_shrink_value_per_day_per_item  \
# address1
# #501 PACWEST/JACKSON                                         NaN
# #505 PACWEST/JACKSON                                         NaN
# #506 PACWEST/JACKSON                               144573.994145
# #508 PACWEST/JACKSON                               144573.887563
# #509 PACWEST/JACKSON                                         NaN
#
#                               period2_pred_date  \
# address1
# #501 PACWEST/JACKSON                        NaT
# #505 PACWEST/JACKSON                        NaT
# #506 PACWEST/JACKSON 2018-02-04 00:00:00.000000
# #508 PACWEST/JACKSON 2018-03-12 16:00:00.028800
# #509 PACWEST/JACKSON                        NaT
#
#                       period3_forc_shrink_value_per_day_per_item  \
# address1
# #501 PACWEST/JACKSON                                         NaN
# #505 PACWEST/JACKSON                                         NaN
# #506 PACWEST/JACKSON                               210246.623951
# #508 PACWEST/JACKSON                               210245.895782
# #509 PACWEST/JACKSON                                         NaN
#
#                      period3_pred_date  \
# address1
# #501 PACWEST/JACKSON               NaT
# #505 PACWEST/JACKSON               NaT
# #506 PACWEST/JACKSON        2018-03-02
# #508 PACWEST/JACKSON        2018-04-26
# #509 PACWEST/JACKSON               NaT
#
#                       period4_forc_shrink_value_per_day_per_item  \
# address1
# #501 PACWEST/JACKSON                                         NaN
# #505 PACWEST/JACKSON                                         NaN
# #506 PACWEST/JACKSON                               173096.980194
# #508 PACWEST/JACKSON                               173096.617993
# #509 PACWEST/JACKSON                                         NaN
#
#                               period4_pred_date
# address1
# #501 PACWEST/JACKSON                        NaT
# #505 PACWEST/JACKSON                        NaT
# #506 PACWEST/JACKSON 2018-03-28 00:00:00.000000
# #508 PACWEST/JACKSON 2018-06-09 07:59:59.971200
# #509 PACWEST/JACKSON                        NaT
