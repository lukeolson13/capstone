# %%
import pandas as pd
import numpy as np
import pickle
import seaborn as sb
from matplotlib import rc
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.pipeline import Pipeline
from statsmodels.regression.linear_model import OLS
from statsmodels.tools import add_constant
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit
from sklearn.decomposition import PCA
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, MiniBatchKMeans
from sklearn.metrics import silhouette_score, mean_squared_error
from scipy.spatial.distance import pdist, squareform
from scipy.cluster.hierarchy import linkage, dendrogram
import time
from collections import defaultdict

from sklearn import model_selection
from sklearn.feature_selection import SelectFromModel
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.svm import SVR, LinearSVR
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, SGDRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor, NearestNeighbors
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPRegressor
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score, f1_score

from keras.models import Sequential
from keras.layers import Dense, LSTM, Activation, Dropout
from keras.activations import relu, tanh
from keras.optimizers import Adam

#from sknn.mlp import Regressor

from shrink_functions import X_y, time_split, ss
from model_functions import model_clusters, plot_rmse, clust_grid

# %%
# %matplotlib inline
pd.set_option('max_columns',500)
font = {'size': 20}
rc('font', **font)
plt.style.use('seaborn-bright')

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
df = pd.read_pickle('data/SRP/clean_data_public_no_crime_lag2_by_store.pkl')
df_agg = df.groupby(['address1', 'visit_date']).mean().sort_index().reset_index()

cust_table_clust = pd.read_pickle('data/SRP/cust_table_clusters_biased.pkl')
df_agg = df_agg.join(cust_table_clust, on='address1', how='left')

# %%
item_cols = ['item_category_8',
       'item_category_10', 'item_category_16', 'item_category_19',
       'item_category_26', 'item_category_31', 'item_category_38',
       'item_category_41', 'item_category_43', 'item_category_44',
       'item_category_46', 'item_category_58', 'item_category_62',
       'item_category_77', 'item_category_79', 'item_category_90']

for col in item_cols:
    del df_agg[col]
    
id_cols = ['customer_id_2139', 'customer_id_1635139', 'customer_id_1903139',
       'customer_id_2331150', 'customer_id_2741156', 'customer_id_2773156',
       'customer_id_2782156', 'customer_id_2956160', 'customer_id_2977160',
       'customer_id_3083182', 'customer_id_3088198', 'customer_id_3088201',
       'customer_id_3089336', 'customer_id_3093327', 'customer_id_3093329',
       'customer_id_3097348']

for col in id_cols:
    df_agg[col] = df_agg[col].astype(np.uint8)

# %%
reg_cols = pickle.load(open('data/SRP/reg_cols.pkl', 'rb'))
cust_table_agg = pd.read_pickle('data/SRP/cust_table_agg.pkl')

# %% [markdown]
# ## Split into features and targets

# %%
# split into features and targets
non_feature_cols = ['shrink_value', 'shrink_to_sales_value_pct', 'shrink_value_out', 'shrink_to_sales_value_pct_out',
               'shrink_value_ex_del', 'shrink_to_sales_value_pct_ex_del', 'qty_inv_out', 'qty_shrink',
               'qty_shrink_ex_del', 'qty_shrink_out', 'qty_end_inventory', 'qty_f', 'qty_out', 'qty_ex_del',
               'qty_n', 'qty_delivery', 'qty_o', 'qty_d', 'qty_shrink_per_day', 'shrink_value_per_day']
# X y split for forcast model
X, y = X_y(df_agg, non_feature_cols, target_col='shrink_value_per_day')

# time split for forcast test
split_date = pd.to_datetime('12/15/2017')
X_train, X_test, y_train, y_test = time_split(df_agg, 'visit_date', split_date, non_feature_cols, 
                                              target_col='shrink_value_per_day')

# %% [markdown]
# ## Standardize and Scale

# %%
# save off non-scaled version (for naive comparison)
X_train_ns = X_train
X_test_ns = X_test

X_train = ss(X_train, std=True, scale=True)
X_test = ss(X_test, std=True, scale=True)
X = ss(X, std=True, scale=True)

# %%
# create mask of all numberical columns to be used in clustering/modeling

# forcasting columns (what is known months ahead of time)
forc_cols = ['FD_ratio', 'LAPOP1_10', 'POP2010', 'customer_id_1635139',
             'customer_id_1903139', 'customer_id_2139', 'customer_id_2331150',
             'customer_id_2741156', 'customer_id_2773156', 'customer_id_2782156',
             'customer_id_2956160', 'customer_id_2977160', 'customer_id_3083182',
             'customer_id_3088198', 'customer_id_3088201', 'customer_id_3089336',
             'customer_id_3093327', 'customer_id_3093329', 'customer_id_3097348',
             'dens_sq_mile', 'unemp_rate', 'qty_POG_limit', 'unit_price', 
             'shrink_value_per_day_lag1_by_store', 'shrink_value_per_day_lag2_by_store' ]

# mask to be used in calculations
model_mask_cols = forc_cols

# %% [markdown]
# ## Determine Model Params

# %%
model = MLPRegressor()
params = {'hidden_layer_sizes': [(300,), (100,), (50,50), (50,50,50)], 'learning_rate_init': [0.01, 0.001, 0.0001], 
          'activation': ['identity', 'logistic', 'tanh', 'relu'], 'solver': ['adam'],  'max_iter': [700]}
# params = {'hidden_layer_sizes': [(10)], 'learning_rate_init': [0.01], 
#           'activation': ['relu'], 'solver': ['adam'],  'max_iter': [10]}
clust_grid(model, params, X_train, y_train, model_mask_cols)
# Out:
# cluster:  1
# /home/luke/anaconda2/envs/py3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/luke/anaconda2/envs/py3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/luke/anaconda2/envs/py3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/luke/anaconda2/envs/py3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/luke/anaconda2/envs/py3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/luke/anaconda2/envs/py3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/luke/anaconda2/envs/py3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/luke/anaconda2/envs/py3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/luke/anaconda2/envs/py3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/luke/anaconda2/envs/py3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/luke/anaconda2/envs/py3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/luke/anaconda2/envs/py3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/luke/anaconda2/envs/py3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/luke/anaconda2/envs/py3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/luke/anaconda2/envs/py3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# {'activation': 'relu', 'hidden_layer_sizes': (50, 50), 'learning_rate_init': 0.001, 'max_iter': 700, 'solver': 'adam'}
#
#
# cluster:  2
# {'activation': 'identity', 'hidden_layer_sizes': (300,), 'learning_rate_init': 0.0001, 'max_iter': 700, 'solver': 'adam'}
#
#
# cluster:  3
# {'activation': 'identity', 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.001, 'max_iter': 700, 'solver': 'adam'}
#
#
# cluster:  4
# {'activation': 'logistic', 'hidden_layer_sizes': (50, 50), 'learning_rate_init': 0.001, 'max_iter': 700, 'solver': 'adam'}

# %% [markdown]
# ## Train Test Model

# %%
mlp1 = MLPRegressor(alpha=0.001, solver='adam', activation='relu', hidden_layer_sizes=(50,50, 50), 
                    learning_rate_init=0.0001, max_iter=1000)
mlp2 = MLPRegressor(alpha=0.001, solver='adam', activation='identity', hidden_layer_sizes=(100,), 
                    learning_rate_init=0.001, max_iter=1000)
mlp3 = MLPRegressor(alpha=0.001, solver='adam', activation='identity', hidden_layer_sizes=(100,), 
                    learning_rate_init=0.0001, max_iter=1000)
mlp4 = MLPRegressor(alpha=0.001, solver='adam', activation='logistic', hidden_layer_sizes=(50,50), 
                    learning_rate_init=0.001, max_iter=1000)
mlp_list = [mlp1, mlp2, mlp3, mlp4]

cluster_rmse, naive_rmse, test_cluster_models = model_clusters(mlp_list, X_train, X_test, X_test_ns, 'shrink_value_per_day_lag1_by_store', model_mask_cols, y_train, y_test)
# Out:
# cluster:  1
# cluster:  2
# cluster:  3
# cluster:  4

# %%
plot_rmse(cluster_rmse, naive_rmse, num_clusters=len(X_train.cluster.unique()), title='Training Forcast')
# Out:
# Average decrease: -3.8%

# %% [markdown]
# ## Test Model

# %%
def test_model(X_test, y_test, test_cluster_models, col_mask):
    rmse_dict = defaultdict(lambda: defaultdict(lambda: defaultdict(lambda: [])))
    lag1_loc = X_test[col_mask].columns.get_loc('shrink_value_per_day_lag1_by_store')
    lag2_loc = X_test[col_mask].columns.get_loc('shrink_value_per_day_lag2_by_store')
    for add in X_test.address1.unique():
        add_mask = X_test.address1 == add
        foo = X_test[ add_mask ].sort_values('visit_date', ascending=True)
        clust = int(foo.cluster.values[0])
        # set initial lag variables to current value
        naive_pred = foo.shrink_value_per_day_lag1_by_store.values[0]
        lag1_val = naive_pred
        lag2_val = foo.shrink_value_per_day_lag2_by_store.values[0]
        i = 0
        for index, row in foo.iterrows():
            model = test_cluster_models[clust]
            inputs = row[col_mask].values
            inputs[lag1_loc] = lag1_val
            inputs[lag2_loc] = lag2_val
            
            pred = model.predict(inputs.reshape(1, -1))                      
            actual = [y_test[index]]
            naive = [naive_pred]

            pred_rmse = np.sqrt(mean_squared_error(actual, pred))
            naive_rmse = np.sqrt(mean_squared_error(actual, naive))
            rmse_dict['{}'.format(i)]['pred'][clust].append(pred_rmse)
            rmse_dict['{}'.format(i)]['naive'][clust].append(naive_rmse)

            lag2_val = lag1_val
            lag1_val = pred
                                
            i += 1
    return rmse_dict

# %%
rmse_dict = test_model(X_test, y_test, test_cluster_models, model_mask_cols)

# %%
def split_and_plot(rmse_dict):
    num_clusts = len(rmse_dict['0']['pred'])
    for i in rmse_dict.keys():
        cluster_rmse = [0] * num_clusts
        naive_rmse = [0] * num_clusts
        for kind in rmse_dict[i].keys():
            for clust in rmse_dict[i][kind].keys():
                if kind == 'pred':
                    cluster_rmse[int(clust)] = np.mean(rmse_dict[i][kind][clust])
                else:
                    naive_rmse[int(clust)] = np.mean(rmse_dict[i][kind][clust])
        plot_rmse(cluster_rmse, naive_rmse, num_clusts, title='{} Time Period(s) Forward'.format(int(i) + 1))

# %%
split_and_plot(rmse_dict)
# Out:
# Average decrease: 42.8%
# Average decrease: 24.5%
# Average decrease: 39.4%

# %% [markdown]
# ## Forcast

# %%
def fit_forc_model(X, y, model_list, col_mask):
    forc_cluster_models = []
    for index, model in enumerate(model_list):
        clust_mask = X.cluster == str(index)
        model.fit(X[col_mask][clust_mask], y[clust_mask])
        forc_cluster_models.append(model)
    return forc_cluster_models

# %%
forc_cluster_models = fit_forc_model(X, y, mlp_list, model_mask_cols)

# %%
def update_cust_table(cust_table, add, i, pred):
    cust_table.set_value(add, 'period{}_forc_shrink_value_per_day_per_item'.format(i), pred)
    days_i = cust_table.columns.get_loc('days_between_visits')
    days = cust_table.loc[add][days_i]
    last_visit_i = cust_table.columns.get_loc('last_visit')
    last_visit = cust_table.loc[add][last_visit_i]
    next_visit = last_visit.to_datetime()  + pd.to_timedelta(i * days, unit='D')
    cust_table.set_value(add, 'period{}_pred_date'.format(i), next_visit)

# %%
def forc_model(X, y, forc_cluster_models, col_mask, cust_table, num_periods):
    lag1_loc = X[col_mask].columns.get_loc('shrink_value_per_day_lag1_by_store')
    lag2_loc = X[col_mask].columns.get_loc('shrink_value_per_day_lag2_by_store')
    for add in X.address1.unique():
        add_mask = X.address1 == add
        foo = X[ add_mask ].sort_values('visit_date', ascending=False)
        top_index = foo.index[0]
        clust = int(foo.cluster.values[0])
        # get values from last visit for store
        base_input = foo[col_mask].values[0]
        base_actual = y[top_index]
        lag2_val = base_input[lag1_loc]
        lag1_val = base_actual

        for i in range(1, num_periods + 1):
            model = forc_cluster_models[clust]
            inputs = base_input
            inputs[lag1_loc] = lag1_val
            inputs[lag2_loc] = lag2_val
            
            pred = model.predict(inputs.reshape(1, -1))
            update_cust_table(cust_table, add, i, pred)
                
            lag2_val = lag1_val
            lag1_val = pred

# %%
forc_model(X, y, forc_cluster_models, model_mask_cols, cust_table_agg, num_periods=4)
# Out:
# /home/luke/anaconda2/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# /home/luke/anaconda2/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:22: FutureWarning: to_datetime is deprecated. Use self.to_pydatetime()
# /home/luke/anaconda2/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
cust_table_agg.head()
# Out:
#                       qty_shrink_per_day  shrink_value_per_day   POP2010  \
# address1
# #500 PACWEST/JACKSON            0.038061              0.347094  425363.0
# #501 PACWEST/JACKSON            0.041153              0.425020  425363.0
# #502 PACWEST/JACKSON            0.035387              0.358387  425363.0
# #504 PACWEST/JACKSON           -0.047619             -0.404762  735334.0
# #505 PACWEST/JACKSON            0.030754              0.133134  735334.0
#
#                       FD_ratio  unemp_rate  dens_sq_mile           city state  \
# address1
# #500 PACWEST/JACKSON  0.228642        0.07    473.294897  BATTLE GROUND    WA
# #501 PACWEST/JACKSON  0.228642        0.08   2995.890411      VANCOUVER    WA
# #502 PACWEST/JACKSON  0.228642        0.08   2995.890411      VANCOUVER    WA
# #504 PACWEST/JACKSON  0.096296        0.07   4304.958678       PORTLAND    OR
# #505 PACWEST/JACKSON  0.096296        0.06   6111.880661       PORTLAND    OR
#
#                      zip_code customer_id  avg_UPC_per_visit  \
# address1
# #500 PACWEST/JACKSON    98604     3088198           2.250000
# #501 PACWEST/JACKSON    98665     3088198           3.250000
# #502 PACWEST/JACKSON    98665     3088198           2.777778
# #504 PACWEST/JACKSON    97211     3088198           1.000000
# #505 PACWEST/JACKSON    97232     3088198           2.000000
#
#                       days_between_visits last_visit cluster  \
# address1
# #500 PACWEST/JACKSON            19.250000 2017-11-21       3
# #501 PACWEST/JACKSON            22.000000 2017-12-13       3
# #502 PACWEST/JACKSON            19.555556 2017-12-13       3
# #504 PACWEST/JACKSON             0.000000 2017-10-30       2
# #505 PACWEST/JACKSON            25.500000 2017-11-22       2
#
#                       period1_forc_shrink_value_per_day_per_item  \
# address1
# #500 PACWEST/JACKSON                                    0.428779
# #501 PACWEST/JACKSON                                    0.597576
# #502 PACWEST/JACKSON                                    0.803009
# #504 PACWEST/JACKSON                                         NaN
# #505 PACWEST/JACKSON                                    0.530822
#
#                       period2_forc_shrink_value_per_day_per_item  \
# address1
# #500 PACWEST/JACKSON                                    0.650210
# #501 PACWEST/JACKSON                                    0.658172
# #502 PACWEST/JACKSON                                    0.841636
# #504 PACWEST/JACKSON                                         NaN
# #505 PACWEST/JACKSON                                    0.617158
#
#                       period3_forc_shrink_value_per_day_per_item  \
# address1
# #500 PACWEST/JACKSON                                    0.800977
# #501 PACWEST/JACKSON                                    0.665824
# #502 PACWEST/JACKSON                                    0.818517
# #504 PACWEST/JACKSON                                         NaN
# #505 PACWEST/JACKSON                                    0.635988
#
#                       period4_forc_shrink_value_per_day_per_item  \
# address1
# #500 PACWEST/JACKSON                                    0.855098
# #501 PACWEST/JACKSON                                    0.654464
# #502 PACWEST/JACKSON                                    0.790665
# #504 PACWEST/JACKSON                                         NaN
# #505 PACWEST/JACKSON                                    0.635475
#
#                               period1_pred_date          period2_pred_date  \
# address1
# #500 PACWEST/JACKSON 2017-12-10 06:00:00.000000 2017-12-29 12:00:00.000000
# #501 PACWEST/JACKSON 2018-01-04 00:00:00.000000 2018-01-26 00:00:00.000000
# #502 PACWEST/JACKSON 2018-01-01 13:20:00.038400 2018-01-21 02:39:59.990400
# #504 PACWEST/JACKSON 2018-01-23 08:24:00.000000 2018-02-06 16:48:00.000000
# #505 PACWEST/JACKSON 2017-12-17 12:00:00.000000 2018-01-12 00:00:00.000000
#
#                               period3_pred_date          period4_pred_date
# address1
# #500 PACWEST/JACKSON 2018-01-17 18:00:00.000000 2018-02-06 00:00:00.000000
# #501 PACWEST/JACKSON 2018-02-17 00:00:00.000000 2018-03-11 00:00:00.000000
# #502 PACWEST/JACKSON 2018-02-09 16:00:00.028800 2018-03-01 05:19:59.980800
# #504 PACWEST/JACKSON 2018-02-21 01:12:00.000000 2018-03-07 09:36:00.000000
# #505 PACWEST/JACKSON 2018-02-06 12:00:00.000000 2018-03-04 00:00:00.000000

# %%
def pred_shrink_value(cust_table, start_date, end_date, num_periods):
    out_table = cust_table.copy()
    
    start_date = pd.to_datetime(start_date)
    end_date = pd.to_datetime(end_date)
    day_diff = (end_date - start_date).days
    
    shrink_locs = []
    pred_date_locs = []
    for i in range(1, num_periods + 1):
        loc_shrink = cust_table.columns.get_loc('period{}_forc_shrink_value_per_day_per_item'.format(i))
        shrink_locs.append(loc_shrink)
        loc_pred_date = cust_table.columns.get_loc('period{}_pred_date'.format(i))
        pred_date_locs.append(loc_pred_date)
    for index, row in cust_table.iterrows():
        shrink_vals = []
        for place, date_loc in enumerate(pred_date_locs):
            if (row[date_loc] >= start_date) & (row[date_loc] <= end_date):
                shrink_loc = shrink_locs[place]
                shrink_vals.append(row[shrink_loc])
        agg_value = np.mean(shrink_vals) * day_diff
        out_table.set_value(index, 'agg_shrink_value', agg_value)
    return out_table

# %%
agg_table = pred_shrink_value(cust_table_agg, start_date='02/01/2018', end_date='03/01/2018', num_periods=4)
# Out:
# /home/luke/anaconda2/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:24: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /home/luke/anaconda2/envs/py3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/luke/anaconda2/envs/py3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
agg_table.sort_values('agg_shrink_value')
# Out:
#                              qty_shrink_per_day  shrink_value_per_day  \
# address1
# 7 ELEVEN SBT PROGRAM #20722            0.020305             -0.197206
# 7 ELEVEN SBT PROGRAM #34130           -0.008967             -0.069254
# 7 ELEVEN SBT PROGRAM #21888           -0.005082              0.057376
# SPEEDWAY #7853                        -0.056777             -0.746031
# RICH OIL #7785                        -0.093710             -1.237058
# KWIK CHEK #37                          0.090476              0.591952
# 7 ELEVEN SBT PROGRAM #24440           -0.008445             -0.142463
# 7 ELEVEN SBT PROGRAM #33847           -0.033333             -0.166667
# 7 ELEVEN SBT PROGRAM #37297            0.002806              0.048633
# 7 ELEVEN SBT PROGRAM #13619            0.011899             -0.247652
# SPEEDWAY #6786                        -0.094643             -0.164679
# 7 ELEVEN SBT PROGRAM #39347           -0.025608             -0.026138
# MILLER MART #84                        0.035091              0.316943
# 7 ELEVEN SBT PROGRAM #29415           -0.015818              0.059301
# 7 ELEVEN SBT PROGRAM #35300           -0.045647             -0.150946
# PEP BOYS #795                          0.011905              0.065357
# 7 ELEVEN SBT PROGRAM #13623           -0.053968             -0.133651
# 7 ELEVEN SBT PROGRAM #24483            0.006603              0.263368
# 7 ELEVEN SBT PROGRAM #24131           -0.171895             -0.620338
# 7 ELEVEN SBT PROGRAM #36897           -0.046131             -0.209747
# 7 ELEVEN SBT PROGRAM #11027           -0.041911             -0.280812
# 7 ELEVEN SBT PROGRAM #39622            0.016570              0.096933
# 7 ELEVEN SBT PROGRAM #36735            0.020580              0.103901
# 7 ELEVEN SBT PROGRAM #27211           -0.009208             -0.072062
# 7 ELEVEN SBT PROGRAM #33382            0.037032              0.056240
# 7 ELEVEN SBT PROGRAM #37461            0.079556              0.367077
# 7 ELEVEN SBT PROGRAM #12214           -0.037377             -0.256921
# 7 ELEVEN SBT PROGRAM #11510            0.036726              0.064994
# 7 ELEVEN SBT PROGRAM #11452            0.019349             -0.014700
# 7 ELEVEN SBT PROGRAM #25290            0.006211              0.080481
# ...                                         ...                   ...
# SPEEDWAY #7652                         0.004203              0.050482
# SPEEDWAY #7661                         0.012987              0.027143
# SPEEDWAY #7697                         0.131923              0.217311
# SPEEDWAY #7711                         0.019758              0.046887
# SPEEDWAY #7790                         0.000000              0.000000
# SPEEDWAY #7829                         0.023268              0.039475
# SPEEDWAY #7838                         0.518519              0.902222
# SPEEDWAY #7839                         0.000000              0.000000
# SPEEDWAY #7843                         0.438183              0.762439
# SPEEDWAY #7844                        -0.022360             -0.054534
# SPEEDWAY #7849                         0.014103              0.024538
# SPEEDWAY #7851                        -0.428571             -0.745714
# SPEEDWAY #7877                         0.036489              0.269387
# SPEEDWAY #7939                        -0.066631             -0.112679
# SPEEDWAY #7993                        -0.019145             -0.115879
# SPEEDWAY #8202                        -0.049842              0.038403
# SPEEDWAY #8211                         0.003014              0.058181
# SPEEDWAY #8263                         0.083333              0.178214
# SPEEDWAY #8309                         0.072719              0.252226
# SPEEDWAY #8317                        -0.255772             -0.337284
# SPEEDWAY #8534                         0.044533              0.158897
# SPEEDWAY #8724                        -0.286636             -0.993350
# SPEEDWAY #8848                        -0.029812              0.366201
# SPEEDWAY #8854                         0.139667              0.244431
# SPEEDWAY #9326                        -0.164042             -0.033018
# SPEEDWAY #9574                         0.116629              0.820738
# STAPLES #1124                          0.125000              0.753036
# STAPLES #154                           0.000000              0.000000
# STAPLES #837                           0.011765              0.176471
# STAPLES #953                           0.067288              0.511004
#
#                                POP2010  FD_ratio  unemp_rate  dens_sq_mile  \
# address1
# 7 ELEVEN SBT PROGRAM #20722  3095313.0  0.146954        0.07   3952.688495
# 7 ELEVEN SBT PROGRAM #34130  1809034.0  0.314834        0.05    305.125543
# 7 ELEVEN SBT PROGRAM #21888  1029655.0  0.129198        0.06   5528.067561
# SPEEDWAY #7853               1339532.0  0.057037        0.04   1932.639692
# RICH OIL #7785                250331.0  0.323153        0.11   2471.145038
# KWIK CHEK #37                  86129.0  0.084764        0.06     27.100907
# 7 ELEVEN SBT PROGRAM #24440  9818605.0  0.069501        0.09  12649.706980
# 7 ELEVEN SBT PROGRAM #33847   703462.0  0.354518        0.05   1194.844297
# 7 ELEVEN SBT PROGRAM #37297   277789.0  0.447562        0.11   1645.534256
# 7 ELEVEN SBT PROGRAM #13619  3095313.0  0.146954        0.07   2267.090043
# SPEEDWAY #6786               1526006.0  0.012294        0.12   5520.092874
# 7 ELEVEN SBT PROGRAM #39347  9818605.0  0.069501        0.10   5698.094955
# MILLER MART #84                99863.0  0.241853        0.04    467.239459
# 7 ELEVEN SBT PROGRAM #29415  9818605.0  0.069501        0.07   3404.583169
# 7 ELEVEN SBT PROGRAM #35300  1585873.0  0.000001        0.09  34368.078180
# PEP BOYS #795                  47420.0  0.397606        0.12     81.677626
# 7 ELEVEN SBT PROGRAM #13623  3095313.0  0.146954        0.08   6023.812656
# 7 ELEVEN SBT PROGRAM #24483  9818605.0  0.069501        0.15    381.965366
# 7 ELEVEN SBT PROGRAM #24131  9818605.0  0.069501        0.09   8403.563397
# 7 ELEVEN SBT PROGRAM #36897   280895.0  0.314648        0.08   1136.373749
# 7 ELEVEN SBT PROGRAM #11027   576567.0  0.419419        0.09   3110.458284
# 7 ELEVEN SBT PROGRAM #39622   572003.0  0.144832        0.05   5201.190139
# 7 ELEVEN SBT PROGRAM #36735  1280122.0  0.205424        0.07   4938.041080
# 7 ELEVEN SBT PROGRAM #27211   441603.0  0.220765        0.11   1925.239331
# 7 ELEVEN SBT PROGRAM #33382  5194675.0  0.074975        0.05  32161.977830
# 7 ELEVEN SBT PROGRAM #37461   494919.0  0.416931        0.15   4907.913785
# 7 ELEVEN SBT PROGRAM #12214  2368139.0  0.180084        0.08   6441.145281
# 7 ELEVEN SBT PROGRAM #11510  1503085.0  0.254161        0.06   1829.430227
# 7 ELEVEN SBT PROGRAM #11452   809858.0  0.256468        0.09   4172.526650
# 7 ELEVEN SBT PROGRAM #25290   299630.0  0.215887        0.07   1992.551440
# ...                                ...       ...         ...           ...
# SPEEDWAY #7652                154727.0  0.240954        0.05    651.333034
# SPEEDWAY #7661                744344.0  0.314677        0.05   1292.131653
# SPEEDWAY #7697                 62259.0  0.339566        0.09    209.271116
# SPEEDWAY #7711                 49221.0  0.118140        0.10    176.321573
# SPEEDWAY #7790               1493350.0  0.271372        0.06   3700.160557
# SPEEDWAY #7829               2504700.0  0.000149        0.13  30862.605310
# SPEEDWAY #7838               1385108.0  0.006288        0.16  85016.699410
# SPEEDWAY #7839               1493350.0  0.271372        0.06   4984.756475
# SPEEDWAY #7843               1493350.0  0.271372        0.07   7735.488898
# SPEEDWAY #7844               1493350.0  0.271372        0.08   5271.355170
# SPEEDWAY #7849               1339532.0  0.057037        0.07   5960.367691
# SPEEDWAY #7851               1339532.0  0.057037        0.05   7248.639826
# SPEEDWAY #7877                468730.0  0.009453        0.08   8395.600893
# SPEEDWAY #7939                488406.0  0.262130        0.11    802.971111
# SPEEDWAY #7993                 60585.0  0.062068        0.12    201.240835
# SPEEDWAY #8202                350670.0  0.413023        0.06   2311.156187
# SPEEDWAY #8211                 81234.0  0.087752        0.16    360.505323
# SPEEDWAY #8263                 59495.0  0.287794        0.16    192.117066
# SPEEDWAY #8309               5194675.0  0.074975        0.13  13027.712170
# SPEEDWAY #8317               5194675.0  0.074975        0.07  18194.823160
# SPEEDWAY #8534                172780.0  0.272762        0.08    493.573492
# SPEEDWAY #8724               1820584.0  0.148664        0.08   2719.114799
# SPEEDWAY #8848               1202362.0  0.306465        0.11   2946.187128
# SPEEDWAY #8854                840978.0  0.238933        0.11   5250.636132
# SPEEDWAY #9326                 36743.0  0.073529        0.02     87.963295
# SPEEDWAY #9574                802374.0  0.304291        0.20   2150.524368
# STAPLES #1124                 295223.0  0.432442        0.04    982.204813
# STAPLES #154                  215888.0  0.496686        0.09   1639.399581
# STAPLES #837                  215888.0  0.496686        0.08    767.099002
# STAPLES #953                 1585873.0  0.000001        0.07  97263.888890
#
#                                             city state zip_code customer_id  \
# address1
# 7 ELEVEN SBT PROGRAM #20722            SAN DIEGO    CA    92120     2773156
# 7 ELEVEN SBT PROGRAM #34130             BENBROOK    TX    76126     2773156
# 7 ELEVEN SBT PROGRAM #21888       SALT LAKE CITY    UT    84106     2773156
# SPEEDWAY #7853                           SYOSSET    NY    11791     2331150
# RICH OIL #7785                         KALAMAZOO    MI    49008     2331150
# KWIK CHEK #37                         WOLFE CITY    TX    75496     3083182
# 7 ELEVEN SBT PROGRAM #24440              GARDENA    CA    90247     2773156
# 7 ELEVEN SBT PROGRAM #33847          LAKE ZURICH    IL    60047     2773156
# 7 ELEVEN SBT PROGRAM #37297     PORT SAINT LUCIE    FL    34952     2773156
# 7 ELEVEN SBT PROGRAM #13619            ESCONDIDO    CA    92025     2773156
# SPEEDWAY #6786                      PHILADELPHIA    PA    19114     2331150
# 7 ELEVEN SBT PROGRAM #39347         BALDWIN PARK    CA    91706     2773156
# MILLER MART #84                   MECHANICSVILLE    VA    23111     2741156
# 7 ELEVEN SBT PROGRAM #29415       WOODLAND HILLS    CA    91364     2773156
# 7 ELEVEN SBT PROGRAM #35300             NEW YORK    NY    10001     2773156
# PEP BOYS #795                            NOGALES    AZ    85621     3089336
# 7 ELEVEN SBT PROGRAM #13623            SAN DIEGO    CA    92109     2773156
# 7 ELEVEN SBT PROGRAM #24483             PALMDALE    CA    93550     2773156
# 7 ELEVEN SBT PROGRAM #24131          LOS ANGELES    CA    90046     2773156
# 7 ELEVEN SBT PROGRAM #36897                 HOLT    MI    48842     2773156
# 7 ELEVEN SBT PROGRAM #11027            BRICKTOWN    NJ    08724     2773156
# 7 ELEVEN SBT PROGRAM #39622               AURORA    CO    80014     2773156
# 7 ELEVEN SBT PROGRAM #36735                PARMA    OH    44129     2773156
# 7 ELEVEN SBT PROGRAM #27211               AURORA    CO    80011     2773156
# 7 ELEVEN SBT PROGRAM #33382              CHICAGO    IL    60610     2773156
# 7 ELEVEN SBT PROGRAM #37461             BROCKTON    MA    02301     2773156
# 7 ELEVEN SBT PROGRAM #12214               DALLAS    TX    75240     2773156
# 7 ELEVEN SBT PROGRAM #11510            BILLERICA    MA    01821     2773156
# 7 ELEVEN SBT PROGRAM #11452               EDISON    NJ    08817     2773156
# 7 ELEVEN SBT PROGRAM #25290         FORT COLLINS    CO    80525     2773156
# ...                                          ...   ...      ...         ...
# SPEEDWAY #7652                            SCOTIA    NY    12302     2331150
# SPEEDWAY #7661                          FAIRPORT    NY    14450     2331150
# SPEEDWAY #7697                           ONEONTA    NY    13820     2331150
# SPEEDWAY #7711               CASTLETON-ON-HUDSON    NY    12414     2331150
# SPEEDWAY #7790                          HOLBROOK    NY    11741     2331150
# SPEEDWAY #7829                          BROOKLYN    NY    11224     2331150
# SPEEDWAY #7838                             BRONX    NY    10456     2331150
# SPEEDWAY #7839                      WEST BABYLON    NY    11704     2331150
# SPEEDWAY #7843                          COPIAGUE    NY    11726     2331150
# SPEEDWAY #7844                     NORTH BABYLON    NY    11703     2331150
# SPEEDWAY #7849                        HICKSVILLE    NY    11801     2331150
# SPEEDWAY #7851                  ROCKVILLE CENTER    NY    11570     2331150
# SPEEDWAY #7877                     STATEN ISLAND    NY    10303     2331150
# SPEEDWAY #7939                        GREENSBORO    NC    27409     2331150
# SPEEDWAY #7993                         ALBEMARLE    NC    28001     2331150
# SPEEDWAY #8202                    WINSTON- SALEM    NC    27104     2331150
# SPEEDWAY #8211                            WILSON    NC    27893     2331150
# SPEEDWAY #8263                           KINSTON    NC    28501     2331150
# SPEEDWAY #8309                           CHICAGO    IL    60608     2331150
# SPEEDWAY #8317                           CHICAGO    IL    60618     2331150
# SPEEDWAY #8534                    WEST LAFAYETTE    IN    47906     2331150
# SPEEDWAY #8724                            CANTON    MI    48187     2331150
# SPEEDWAY #8848                        SOUTHFIELD    MI    48075     2331150
# SPEEDWAY #8854                  ST. CLAIR SHORES    MI    48081     2331150
# SPEEDWAY #9326                               MAN    WV    25635     2331150
# SPEEDWAY #9574                        CINCINNATI    OH    45204     2331150
# STAPLES #1124                           SEABROOK    NH    03874     2956160
# STAPLES #154                             HYANNIS    MA    02601     2956160
# STAPLES #837                            FALMOUTH    MA    02540     2956160
# STAPLES #953                            NEW YORK    NY    10003     2956160
#
#                              avg_UPC_per_visit  days_between_visits  \
# address1
# 7 ELEVEN SBT PROGRAM #20722           1.750000            56.250000
# 7 ELEVEN SBT PROGRAM #34130           2.000000            32.571429
# 7 ELEVEN SBT PROGRAM #21888           3.571429            34.000000
# SPEEDWAY #7853                        1.666667            67.000000
# RICH OIL #7785                        1.250000            24.500000
# KWIK CHEK #37                         1.250000            58.000000
# 7 ELEVEN SBT PROGRAM #24440           3.166667            34.500000
# 7 ELEVEN SBT PROGRAM #33847           1.666667            63.666667
# 7 ELEVEN SBT PROGRAM #37297           2.000000            52.250000
# 7 ELEVEN SBT PROGRAM #13619           2.000000            34.000000
# SPEEDWAY #6786                        1.000000            55.750000
# 7 ELEVEN SBT PROGRAM #39347           1.800000            40.400000
# MILLER MART #84                       1.800000            25.800000
# 7 ELEVEN SBT PROGRAM #29415           1.800000            41.800000
# 7 ELEVEN SBT PROGRAM #35300           2.666667            30.666667
# PEP BOYS #795                         2.666667            19.666667
# 7 ELEVEN SBT PROGRAM #13623           1.666667            67.333333
# 7 ELEVEN SBT PROGRAM #24483           1.250000            50.000000
# 7 ELEVEN SBT PROGRAM #24131           2.833333            33.833333
# 7 ELEVEN SBT PROGRAM #36897           2.000000            51.250000
# 7 ELEVEN SBT PROGRAM #11027           2.400000            46.200000
# 7 ELEVEN SBT PROGRAM #39622           1.666667            34.166667
# 7 ELEVEN SBT PROGRAM #36735           4.000000            65.000000
# 7 ELEVEN SBT PROGRAM #27211           2.500000            36.000000
# 7 ELEVEN SBT PROGRAM #33382           2.600000            44.600000
# 7 ELEVEN SBT PROGRAM #37461           2.750000            39.500000
# 7 ELEVEN SBT PROGRAM #12214           1.666667            53.333333
# 7 ELEVEN SBT PROGRAM #11510           3.000000            28.400000
# 7 ELEVEN SBT PROGRAM #11452           3.750000            56.000000
# 7 ELEVEN SBT PROGRAM #25290           1.333333            59.000000
# ...                                        ...                  ...
# SPEEDWAY #7652                        1.857143            34.714286
# SPEEDWAY #7661                        1.571429            26.714286
# SPEEDWAY #7697                        1.333333            77.333333
# SPEEDWAY #7711                        1.571429            30.142857
# SPEEDWAY #7790                        1.000000            45.500000
# SPEEDWAY #7829                        1.333333            39.333333
# SPEEDWAY #7838                        1.000000             0.000000
# SPEEDWAY #7839                        2.000000             0.000000
# SPEEDWAY #7843                        1.000000            32.000000
# SPEEDWAY #7844                        1.000000            47.800000
# SPEEDWAY #7849                        1.000000            19.500000
# SPEEDWAY #7851                        1.000000             6.500000
# SPEEDWAY #7877                        1.583333            15.833333
# SPEEDWAY #7939                        1.750000            15.666667
# SPEEDWAY #7993                        2.133333            15.800000
# SPEEDWAY #8202                        2.000000            17.900000
# SPEEDWAY #8211                        2.833333            41.166667
# SPEEDWAY #8263                        1.200000            49.000000
# SPEEDWAY #8309                        1.750000            47.250000
# SPEEDWAY #8317                        1.428571            19.285714
# SPEEDWAY #8534                        3.750000            15.250000
# SPEEDWAY #8724                        2.000000            40.833333
# SPEEDWAY #8848                        2.357143            16.642857
# SPEEDWAY #8854                        2.352941            15.058824
# SPEEDWAY #9326                        1.714286            22.857143
# SPEEDWAY #9574                        3.411765            15.235294
# STAPLES #1124                         2.000000            28.000000
# STAPLES #154                          1.000000             0.000000
# STAPLES #837                          1.000000             0.000000
# STAPLES #953                          1.000000            10.500000
#
#                             last_visit cluster  \
# address1
# 7 ELEVEN SBT PROGRAM #20722 2017-12-21       2
# 7 ELEVEN SBT PROGRAM #34130 2018-01-02       3
# 7 ELEVEN SBT PROGRAM #21888 2018-01-02       2
# SPEEDWAY #7853              2017-11-29       2
# RICH OIL #7785              2018-01-09       3
# KWIK CHEK #37               2017-12-19       2
# 7 ELEVEN SBT PROGRAM #24440 2018-01-08       1
# 7 ELEVEN SBT PROGRAM #33847 2017-12-15       3
# 7 ELEVEN SBT PROGRAM #37297 2017-12-11       3
# 7 ELEVEN SBT PROGRAM #13619 2018-01-08       2
# SPEEDWAY #6786              2017-12-18       2
# 7 ELEVEN SBT PROGRAM #39347 2018-01-02       1
# MILLER MART #84             2017-11-02       3
# 7 ELEVEN SBT PROGRAM #29415 2018-01-04       1
# 7 ELEVEN SBT PROGRAM #35300 2018-01-08       1
# PEP BOYS #795               2017-11-16       3
# 7 ELEVEN SBT PROGRAM #13623 2017-12-18       2
# 7 ELEVEN SBT PROGRAM #24483 2018-01-02       1
# 7 ELEVEN SBT PROGRAM #24131 2017-12-19       1
# 7 ELEVEN SBT PROGRAM #36897 2017-12-14       3
# 7 ELEVEN SBT PROGRAM #11027 2017-12-21       3
# 7 ELEVEN SBT PROGRAM #39622 2018-01-03       2
# 7 ELEVEN SBT PROGRAM #36735 2017-12-19       3
# 7 ELEVEN SBT PROGRAM #27211 2018-01-08       2
# 7 ELEVEN SBT PROGRAM #33382 2017-12-19       1
# 7 ELEVEN SBT PROGRAM #37461 2018-01-05       3
# 7 ELEVEN SBT PROGRAM #12214 2017-12-18       2
# 7 ELEVEN SBT PROGRAM #11510 2018-01-04       3
# 7 ELEVEN SBT PROGRAM #11452 2018-01-03       3
# 7 ELEVEN SBT PROGRAM #25290 2017-12-15       2
# ...                                ...     ...
# SPEEDWAY #7652              2017-12-22       3
# SPEEDWAY #7661              2017-10-04       3
# SPEEDWAY #7697              2017-12-20       3
# SPEEDWAY #7711              2017-12-01       2
# SPEEDWAY #7790              2017-11-28       3
# SPEEDWAY #7829              2017-11-14       1
# SPEEDWAY #7838              2017-05-23       1
# SPEEDWAY #7839              2017-09-19       3
# SPEEDWAY #7843              2017-08-28       0
# SPEEDWAY #7844              2017-11-29       2
# SPEEDWAY #7849              2017-08-08       2
# SPEEDWAY #7851              2017-07-05       2
# SPEEDWAY #7877              2017-10-25       2
# SPEEDWAY #7939              2017-10-23       2
# SPEEDWAY #7993              2017-11-22       2
# SPEEDWAY #8202              2017-10-02       3
# SPEEDWAY #8211              2017-12-20       2
# SPEEDWAY #8263              2017-11-29       2
# SPEEDWAY #8309              2017-11-28       1
# SPEEDWAY #8317              2017-09-13       1
# SPEEDWAY #8534              2017-11-15       3
# SPEEDWAY #8724              2017-12-18       2
# SPEEDWAY #8848              2017-11-09       3
# SPEEDWAY #8854              2017-12-01       0
# SPEEDWAY #9326              2017-10-16       2
# SPEEDWAY #9574              2017-11-30       0
# STAPLES #1124               2018-01-03       0
# STAPLES #154                2017-10-26       3
# STAPLES #837                2017-10-26       3
# STAPLES #953                2017-11-09       1
#
#                              period1_forc_shrink_value_per_day_per_item  \
# address1
# 7 ELEVEN SBT PROGRAM #20722                                   -0.862758
# 7 ELEVEN SBT PROGRAM #34130                                   -0.772338
# 7 ELEVEN SBT PROGRAM #21888                                   -0.624409
# SPEEDWAY #7853                                                -0.544865
# RICH OIL #7785                                                -2.120220
# KWIK CHEK #37                                                 -0.430960
# 7 ELEVEN SBT PROGRAM #24440                                   -0.424569
# 7 ELEVEN SBT PROGRAM #33847                                   -0.382250
# 7 ELEVEN SBT PROGRAM #37297                                   -0.331331
# 7 ELEVEN SBT PROGRAM #13619                                   -0.317557
# SPEEDWAY #6786                                                -0.308779
# 7 ELEVEN SBT PROGRAM #39347                                   -0.308539
# MILLER MART #84                                                0.208595
# 7 ELEVEN SBT PROGRAM #29415                                   -0.299073
# 7 ELEVEN SBT PROGRAM #35300                                   -0.288937
# PEP BOYS #795                                                  0.012902
# 7 ELEVEN SBT PROGRAM #13623                                   -0.214831
# 7 ELEVEN SBT PROGRAM #24483                                   -0.213746
# 7 ELEVEN SBT PROGRAM #24131                                   -1.013178
# 7 ELEVEN SBT PROGRAM #36897                                   -0.199782
# 7 ELEVEN SBT PROGRAM #11027                                   -0.190258
# 7 ELEVEN SBT PROGRAM #39622                                   -0.189897
# 7 ELEVEN SBT PROGRAM #36735                                   -0.166787
# 7 ELEVEN SBT PROGRAM #27211                                   -0.166014
# 7 ELEVEN SBT PROGRAM #33382                                   -0.154733
# 7 ELEVEN SBT PROGRAM #37461                                   -0.153538
# 7 ELEVEN SBT PROGRAM #12214                                   -0.149497
# 7 ELEVEN SBT PROGRAM #11510                                   -0.143670
# 7 ELEVEN SBT PROGRAM #11452                                   -0.128859
# 7 ELEVEN SBT PROGRAM #25290                                   -0.128827
# ...                                                                 ...
# SPEEDWAY #7652                                                 0.563482
# SPEEDWAY #7661                                                 0.419763
# SPEEDWAY #7697                                                 0.537950
# SPEEDWAY #7711                                                 0.103027
# SPEEDWAY #7790                                                      NaN
# SPEEDWAY #7829                                                 0.136092
# SPEEDWAY #7838                                                      NaN
# SPEEDWAY #7839                                                      NaN
# SPEEDWAY #7843                                                -0.011839
# SPEEDWAY #7844                                                 0.395955
# SPEEDWAY #7849                                                      NaN
# SPEEDWAY #7851                                                      NaN
# SPEEDWAY #7877                                                 0.823748
# SPEEDWAY #7939                                                 0.413028
# SPEEDWAY #7993                                                 0.245859
# SPEEDWAY #8202                                                 0.253705
# SPEEDWAY #8211                                                 0.330036
# SPEEDWAY #8263                                                 0.320972
# SPEEDWAY #8309                                                 0.951212
# SPEEDWAY #8317                                                -0.621366
# SPEEDWAY #8534                                                 0.611807
# SPEEDWAY #8724                                                -0.522869
# SPEEDWAY #8848                                                 1.228832
# SPEEDWAY #8854                                                 0.854207
# SPEEDWAY #9326                                                 0.237002
# SPEEDWAY #9574                                                -0.034743
# STAPLES #1124                                                       NaN
# STAPLES #154                                                        NaN
# STAPLES #837                                                        NaN
# STAPLES #953                                                        NaN
#
#                              period2_forc_shrink_value_per_day_per_item  \
# address1
# 7 ELEVEN SBT PROGRAM #20722                                    0.099403
# 7 ELEVEN SBT PROGRAM #34130                                    0.041885
# 7 ELEVEN SBT PROGRAM #21888                                   -0.087508
# SPEEDWAY #7853                                                 0.455560
# RICH OIL #7785                                                 1.220999
# KWIK CHEK #37                                                 -0.029746
# 7 ELEVEN SBT PROGRAM #24440                                    0.084357
# 7 ELEVEN SBT PROGRAM #33847                                    0.161087
# 7 ELEVEN SBT PROGRAM #37297                                    0.177215
# 7 ELEVEN SBT PROGRAM #13619                                    0.219500
# SPEEDWAY #6786                                                 0.152638
# 7 ELEVEN SBT PROGRAM #39347                                    0.055090
# MILLER MART #84                                               -0.009156
# 7 ELEVEN SBT PROGRAM #29415                                    0.001521
# 7 ELEVEN SBT PROGRAM #35300                                   -0.037361
# PEP BOYS #795                                                 -0.099856
# 7 ELEVEN SBT PROGRAM #13623                                    0.211728
# 7 ELEVEN SBT PROGRAM #24483                                    0.135474
# 7 ELEVEN SBT PROGRAM #24131                                   -0.201873
# 7 ELEVEN SBT PROGRAM #36897                                    0.300718
# 7 ELEVEN SBT PROGRAM #11027                                    0.371456
# 7 ELEVEN SBT PROGRAM #39622                                    0.171397
# 7 ELEVEN SBT PROGRAM #36735                                    0.448592
# 7 ELEVEN SBT PROGRAM #27211                                    0.245599
# 7 ELEVEN SBT PROGRAM #33382                                    0.172833
# 7 ELEVEN SBT PROGRAM #37461                                    0.407869
# 7 ELEVEN SBT PROGRAM #12214                                    0.360479
# 7 ELEVEN SBT PROGRAM #11510                                    0.340732
# 7 ELEVEN SBT PROGRAM #11452                                    0.453158
# 7 ELEVEN SBT PROGRAM #25290                                    0.205325
# ...                                                                 ...
# SPEEDWAY #7652                                                 0.738707
# SPEEDWAY #7661                                                 0.662206
# SPEEDWAY #7697                                                 0.699443
# SPEEDWAY #7711                                                 0.180789
# SPEEDWAY #7790                                                      NaN
# SPEEDWAY #7829                                                 0.161207
# SPEEDWAY #7838                                                      NaN
# SPEEDWAY #7839                                                      NaN
# SPEEDWAY #7843                                                 0.025149
# SPEEDWAY #7844                                                 0.379765
# SPEEDWAY #7849                                                      NaN
# SPEEDWAY #7851                                                      NaN
# SPEEDWAY #7877                                                 0.782256
# SPEEDWAY #7939                                                 0.457267
# SPEEDWAY #7993                                                 0.341245
# SPEEDWAY #8202                                                 0.463212
# SPEEDWAY #8211                                                 0.532963
# SPEEDWAY #8263                                                 0.459072
# SPEEDWAY #8309                                                 0.809844
# SPEEDWAY #8317                                                 0.042763
# SPEEDWAY #8534                                                 0.976835
# SPEEDWAY #8724                                                 0.124162
# SPEEDWAY #8848                                                 0.894436
# SPEEDWAY #8854                                                 0.898263
# SPEEDWAY #9326                                                 0.325340
# SPEEDWAY #9574                                                 0.413768
# STAPLES #1124                                                       NaN
# STAPLES #154                                                        NaN
# STAPLES #837                                                        NaN
# STAPLES #953                                                        NaN
#
#                              period3_forc_shrink_value_per_day_per_item  \
# address1
# 7 ELEVEN SBT PROGRAM #20722                                    0.504469
# 7 ELEVEN SBT PROGRAM #34130                                    0.556416
# 7 ELEVEN SBT PROGRAM #21888                                    0.138603
# SPEEDWAY #7853                                                 0.860039
# RICH OIL #7785                                                 1.570406
# KWIK CHEK #37                                                  0.227720
# 7 ELEVEN SBT PROGRAM #24440                                    0.337231
# 7 ELEVEN SBT PROGRAM #33847                                    0.499474
# 7 ELEVEN SBT PROGRAM #37297                                    0.506593
# 7 ELEVEN SBT PROGRAM #13619                                    0.412505
# SPEEDWAY #6786                                                 0.338442
# 7 ELEVEN SBT PROGRAM #39347                                    0.235805
# MILLER MART #84                                               -0.202277
# 7 ELEVEN SBT PROGRAM #29415                                    0.150901
# 7 ELEVEN SBT PROGRAM #35300                                    0.087655
# PEP BOYS #795                                                 -0.206593
# 7 ELEVEN SBT PROGRAM #13623                                    0.383145
# 7 ELEVEN SBT PROGRAM #24483                                    0.309006
# 7 ELEVEN SBT PROGRAM #24131                                    0.201254
# 7 ELEVEN SBT PROGRAM #36897                                    0.555597
# 7 ELEVEN SBT PROGRAM #11027                                    0.694503
# 7 ELEVEN SBT PROGRAM #39622                                    0.320736
# 7 ELEVEN SBT PROGRAM #36735                                    0.779967
# 7 ELEVEN SBT PROGRAM #27211                                    0.412021
# 7 ELEVEN SBT PROGRAM #33382                                    0.335591
# 7 ELEVEN SBT PROGRAM #37461                                    0.677110
# 7 ELEVEN SBT PROGRAM #12214                                    0.560794
# 7 ELEVEN SBT PROGRAM #11510                                    0.598569
# 7 ELEVEN SBT PROGRAM #11452                                    0.764269
# 7 ELEVEN SBT PROGRAM #25290                                    0.349174
# ...                                                                 ...
# SPEEDWAY #7652                                                 0.775532
# SPEEDWAY #7661                                                 0.739081
# SPEEDWAY #7697                                                 0.728204
# SPEEDWAY #7711                                                 0.205363
# SPEEDWAY #7790                                                      NaN
# SPEEDWAY #7829                                                 0.173673
# SPEEDWAY #7838                                                      NaN
# SPEEDWAY #7839                                                      NaN
# SPEEDWAY #7843                                                 0.043734
# SPEEDWAY #7844                                                 0.353553
# SPEEDWAY #7849                                                      NaN
# SPEEDWAY #7851                                                      NaN
# SPEEDWAY #7877                                                 0.747933
# SPEEDWAY #7939                                                 0.438845
# SPEEDWAY #7993                                                 0.369764
# SPEEDWAY #8202                                                 0.566238
# SPEEDWAY #8211                                                 0.602376
# SPEEDWAY #8263                                                 0.497516
# SPEEDWAY #8309                                                 0.739561
# SPEEDWAY #8317                                                 0.372773
# SPEEDWAY #8534                                                 1.090328
# SPEEDWAY #8724                                                 0.393456
# SPEEDWAY #8848                                                 0.756478
# SPEEDWAY #8854                                                 0.845235
# SPEEDWAY #9326                                                 0.345648
# SPEEDWAY #9574                                                 0.796520
# STAPLES #1124                                                       NaN
# STAPLES #154                                                        NaN
# STAPLES #837                                                        NaN
# STAPLES #953                                                        NaN
#
#                              period4_forc_shrink_value_per_day_per_item  \
# address1
# 7 ELEVEN SBT PROGRAM #20722                                    0.614433
# 7 ELEVEN SBT PROGRAM #34130                                    0.741771
# 7 ELEVEN SBT PROGRAM #21888                                    0.200010
# SPEEDWAY #7853                                                 0.964481
# RICH OIL #7785                                                 1.203341
# KWIK CHEK #37                                                  0.326055
# 7 ELEVEN SBT PROGRAM #24440                                    0.462852
# 7 ELEVEN SBT PROGRAM #33847                                    0.624779
# 7 ELEVEN SBT PROGRAM #37297                                    0.635080
# 7 ELEVEN SBT PROGRAM #13619                                    0.454273
# SPEEDWAY #6786                                                 0.386168
# 7 ELEVEN SBT PROGRAM #39347                                    0.325580
# MILLER MART #84                                               -0.307804
# 7 ELEVEN SBT PROGRAM #29415                                    0.225109
# 7 ELEVEN SBT PROGRAM #35300                                    0.149760
# PEP BOYS #795                                                 -0.266752
# 7 ELEVEN SBT PROGRAM #13623                                    0.427058
# 7 ELEVEN SBT PROGRAM #24483                                    0.395212
# 7 ELEVEN SBT PROGRAM #24131                                    0.401516
# 7 ELEVEN SBT PROGRAM #36897                                    0.622779
# 7 ELEVEN SBT PROGRAM #11027                                    0.793219
# 7 ELEVEN SBT PROGRAM #39622                                    0.360389
# 7 ELEVEN SBT PROGRAM #36735                                    0.865591
# 7 ELEVEN SBT PROGRAM #27211                                    0.454995
# 7 ELEVEN SBT PROGRAM #33382                                    0.416444
# 7 ELEVEN SBT PROGRAM #37461                                    0.734074
# 7 ELEVEN SBT PROGRAM #12214                                    0.610555
# 7 ELEVEN SBT PROGRAM #11510                                    0.670540
# 7 ELEVEN SBT PROGRAM #11452                                    0.844717
# 7 ELEVEN SBT PROGRAM #25290                                    0.389243
# ...                                                                 ...
# SPEEDWAY #7652                                                 0.755656
# SPEEDWAY #7661                                                 0.732171
# SPEEDWAY #7697                                                 0.705569
# SPEEDWAY #7711                                                 0.209412
# SPEEDWAY #7790                                                      NaN
# SPEEDWAY #7829                                                 0.179866
# SPEEDWAY #7838                                                      NaN
# SPEEDWAY #7839                                                      NaN
# SPEEDWAY #7843                                                 0.042669
# SPEEDWAY #7844                                                 0.340208
# SPEEDWAY #7849                                                      NaN
# SPEEDWAY #7851                                                      NaN
# SPEEDWAY #7877                                                 0.733203
# SPEEDWAY #7939                                                 0.421946
# SPEEDWAY #7993                                                 0.373768
# SPEEDWAY #8202                                                 0.590935
# SPEEDWAY #8211                                                 0.616075
# SPEEDWAY #8263                                                 0.501627
# SPEEDWAY #8309                                                 0.704646
# SPEEDWAY #8317                                                 0.536713
# SPEEDWAY #8534                                                 1.079884
# SPEEDWAY #8724                                                 0.465565
# SPEEDWAY #8848                                                 0.742489
# SPEEDWAY #8854                                                 0.787504
# SPEEDWAY #9326                                                 0.345739
# SPEEDWAY #9574                                                 0.876494
# STAPLES #1124                                                       NaN
# STAPLES #154                                                        NaN
# STAPLES #837                                                        NaN
# STAPLES #953                                                        NaN
#
#                                      period1_pred_date  \
# address1
# 7 ELEVEN SBT PROGRAM #20722 2018-02-15 06:00:00.000000
# 7 ELEVEN SBT PROGRAM #34130 2018-02-03 13:42:51.465600
# 7 ELEVEN SBT PROGRAM #21888 2018-02-05 00:00:00.000000
# SPEEDWAY #7853              2018-02-04 00:00:00.000000
# RICH OIL #7785              2018-02-02 12:00:00.000000
# KWIK CHEK #37               2018-02-15 00:00:00.000000
# 7 ELEVEN SBT PROGRAM #24440 2018-02-11 12:00:00.000000
# 7 ELEVEN SBT PROGRAM #33847 2018-02-16 16:00:00.028800
# 7 ELEVEN SBT PROGRAM #37297 2018-02-01 06:00:00.000000
# 7 ELEVEN SBT PROGRAM #13619 2018-02-11 00:00:00.000000
# SPEEDWAY #6786              2018-02-11 18:00:00.000000
# 7 ELEVEN SBT PROGRAM #39347 2018-02-11 09:36:00.000000
# MILLER MART #84             2017-11-27 19:12:00.000000
# 7 ELEVEN SBT PROGRAM #29415 2018-02-14 19:12:00.000000
# 7 ELEVEN SBT PROGRAM #35300 2018-02-07 16:00:00.028800
# PEP BOYS #795               2017-12-05 16:00:00.028800
# 7 ELEVEN SBT PROGRAM #13623 2018-02-23 07:59:59.971200
# 7 ELEVEN SBT PROGRAM #24483 2018-02-21 00:00:00.000000
# 7 ELEVEN SBT PROGRAM #24131 2018-01-21 19:59:59.971200
# 7 ELEVEN SBT PROGRAM #36897 2018-02-03 06:00:00.000000
# 7 ELEVEN SBT PROGRAM #11027 2018-02-05 04:48:00.000000
# 7 ELEVEN SBT PROGRAM #39622 2018-02-06 04:00:00.028800
# 7 ELEVEN SBT PROGRAM #36735 2018-02-22 00:00:00.000000
# 7 ELEVEN SBT PROGRAM #27211 2018-02-13 00:00:00.000000
# 7 ELEVEN SBT PROGRAM #33382 2018-02-01 14:24:00.000000
# 7 ELEVEN SBT PROGRAM #37461 2018-02-13 12:00:00.000000
# 7 ELEVEN SBT PROGRAM #12214 2018-02-09 07:59:59.971200
# 7 ELEVEN SBT PROGRAM #11510 2018-02-01 09:36:00.000000
# 7 ELEVEN SBT PROGRAM #11452 2018-02-28 00:00:00.000000
# 7 ELEVEN SBT PROGRAM #25290 2018-02-12 00:00:00.000000
# ...                                                ...
# SPEEDWAY #7652              2018-01-25 17:08:34.310400
# SPEEDWAY #7661              2017-10-30 17:08:34.310400
# SPEEDWAY #7697              2018-03-07 07:59:59.971200
# SPEEDWAY #7711              2017-12-31 03:25:42.844800
# SPEEDWAY #7790              2018-01-23 08:24:00.000000
# SPEEDWAY #7829              2017-12-23 07:59:59.971200
# SPEEDWAY #7838              2018-01-23 08:24:00.000000
# SPEEDWAY #7839              2018-01-23 08:24:00.000000
# SPEEDWAY #7843              2017-09-29 00:00:00.000000
# SPEEDWAY #7844              2018-01-15 19:12:00.000000
# SPEEDWAY #7849              2018-01-23 08:24:00.000000
# SPEEDWAY #7851              2018-01-23 08:24:00.000000
# SPEEDWAY #7877              2017-11-09 19:59:59.971200
# SPEEDWAY #7939              2017-11-07 16:00:00.028800
# SPEEDWAY #7993              2017-12-07 19:12:00.000000
# SPEEDWAY #8202              2017-10-19 21:36:00.000000
# SPEEDWAY #8211              2018-01-30 04:00:00.028800
# SPEEDWAY #8263              2018-01-17 00:00:00.000000
# SPEEDWAY #8309              2018-01-14 06:00:00.000000
# SPEEDWAY #8317              2017-10-02 06:51:25.689600
# SPEEDWAY #8534              2017-11-30 06:00:00.000000
# SPEEDWAY #8724              2018-01-27 19:59:59.971200
# SPEEDWAY #8848              2017-11-25 15:25:42.844800
# SPEEDWAY #8854              2017-12-16 01:24:42.393600
# SPEEDWAY #9326              2017-11-07 20:34:17.155200
# SPEEDWAY #9574              2017-12-15 05:38:49.401600
# STAPLES #1124               2018-01-23 08:24:00.000000
# STAPLES #154                2018-01-23 08:24:00.000000
# STAPLES #837                2018-01-23 08:24:00.000000
# STAPLES #953                2018-01-23 08:24:00.000000
#
#                                      period2_pred_date  \
# address1
# 7 ELEVEN SBT PROGRAM #20722 2018-04-12 12:00:00.000000
# 7 ELEVEN SBT PROGRAM #34130 2018-03-08 03:25:42.844800
# 7 ELEVEN SBT PROGRAM #21888 2018-03-11 00:00:00.000000
# SPEEDWAY #7853              2018-04-12 00:00:00.000000
# RICH OIL #7785              2018-02-27 00:00:00.000000
# KWIK CHEK #37               2018-04-14 00:00:00.000000
# 7 ELEVEN SBT PROGRAM #24440 2018-03-18 00:00:00.000000
# 7 ELEVEN SBT PROGRAM #33847 2018-04-21 07:59:59.971200
# 7 ELEVEN SBT PROGRAM #37297 2018-03-25 12:00:00.000000
# 7 ELEVEN SBT PROGRAM #13619 2018-03-17 00:00:00.000000
# SPEEDWAY #6786              2018-04-08 12:00:00.000000
# 7 ELEVEN SBT PROGRAM #39347 2018-03-23 19:12:00.000000
# MILLER MART #84             2017-12-23 14:24:00.000000
# 7 ELEVEN SBT PROGRAM #29415 2018-03-28 14:24:00.000000
# 7 ELEVEN SBT PROGRAM #35300 2018-03-10 07:59:59.971200
# PEP BOYS #795               2017-12-25 07:59:59.971200
# 7 ELEVEN SBT PROGRAM #13623 2018-05-01 16:00:00.028800
# 7 ELEVEN SBT PROGRAM #24483 2018-04-12 00:00:00.000000
# 7 ELEVEN SBT PROGRAM #24131 2018-02-24 16:00:00.028800
# 7 ELEVEN SBT PROGRAM #36897 2018-03-26 12:00:00.000000
# 7 ELEVEN SBT PROGRAM #11027 2018-03-23 09:36:00.000000
# 7 ELEVEN SBT PROGRAM #39622 2018-03-12 07:59:59.971200
# 7 ELEVEN SBT PROGRAM #36735 2018-04-28 00:00:00.000000
# 7 ELEVEN SBT PROGRAM #27211 2018-03-21 00:00:00.000000
# 7 ELEVEN SBT PROGRAM #33382 2018-03-18 04:48:00.000000
# 7 ELEVEN SBT PROGRAM #37461 2018-03-25 00:00:00.000000
# 7 ELEVEN SBT PROGRAM #12214 2018-04-03 16:00:00.028800
# 7 ELEVEN SBT PROGRAM #11510 2018-03-01 19:12:00.000000
# 7 ELEVEN SBT PROGRAM #11452 2018-04-25 00:00:00.000000
# 7 ELEVEN SBT PROGRAM #25290 2018-04-12 00:00:00.000000
# ...                                                ...
# SPEEDWAY #7652              2018-03-01 10:17:08.534400
# SPEEDWAY #7661              2017-11-26 10:17:08.534400
# SPEEDWAY #7697              2018-05-23 16:00:00.028800
# SPEEDWAY #7711              2018-01-30 06:51:25.689600
# SPEEDWAY #7790              2018-02-06 16:48:00.000000
# SPEEDWAY #7829              2018-01-31 16:00:00.028800
# SPEEDWAY #7838              2018-02-06 16:48:00.000000
# SPEEDWAY #7839              2018-02-06 16:48:00.000000
# SPEEDWAY #7843              2017-10-31 00:00:00.000000
# SPEEDWAY #7844              2018-03-04 14:24:00.000000
# SPEEDWAY #7849              2018-02-06 16:48:00.000000
# SPEEDWAY #7851              2018-02-06 16:48:00.000000
# SPEEDWAY #7877              2017-11-25 16:00:00.028800
# SPEEDWAY #7939              2017-11-23 07:59:59.971200
# SPEEDWAY #7993              2017-12-23 14:24:00.000000
# SPEEDWAY #8202              2017-11-06 19:12:00.000000
# SPEEDWAY #8211              2018-03-12 07:59:59.971200
# SPEEDWAY #8263              2018-03-07 00:00:00.000000
# SPEEDWAY #8309              2018-03-02 12:00:00.000000
# SPEEDWAY #8317              2017-10-21 13:42:51.465600
# SPEEDWAY #8534              2017-12-15 12:00:00.000000
# SPEEDWAY #8724              2018-03-09 16:00:00.028800
# SPEEDWAY #8848              2017-12-12 06:51:25.689600
# SPEEDWAY #8854              2017-12-31 02:49:24.700800
# SPEEDWAY #9326              2017-11-30 17:08:34.310400
# SPEEDWAY #9574              2017-12-30 11:17:38.803200
# STAPLES #1124               2018-02-06 16:48:00.000000
# STAPLES #154                2018-02-06 16:48:00.000000
# STAPLES #837                2018-02-06 16:48:00.000000
# STAPLES #953                2018-02-06 16:48:00.000000
#
#                                      period3_pred_date  \
# address1
# 7 ELEVEN SBT PROGRAM #20722 2018-06-07 18:00:00.000000
# 7 ELEVEN SBT PROGRAM #34130 2018-04-09 17:08:34.310400
# 7 ELEVEN SBT PROGRAM #21888 2018-04-14 00:00:00.000000
# SPEEDWAY #7853              2018-06-18 00:00:00.000000
# RICH OIL #7785              2018-03-23 12:00:00.000000
# KWIK CHEK #37               2018-06-11 00:00:00.000000
# 7 ELEVEN SBT PROGRAM #24440 2018-04-21 12:00:00.000000
# 7 ELEVEN SBT PROGRAM #33847 2018-06-24 00:00:00.000000
# 7 ELEVEN SBT PROGRAM #37297 2018-05-16 18:00:00.000000
# 7 ELEVEN SBT PROGRAM #13619 2018-04-20 00:00:00.000000
# SPEEDWAY #6786              2018-06-03 06:00:00.000000
# 7 ELEVEN SBT PROGRAM #39347 2018-05-03 04:48:00.000000
# MILLER MART #84             2018-01-18 09:36:00.000000
# 7 ELEVEN SBT PROGRAM #29415 2018-05-09 09:36:00.000000
# 7 ELEVEN SBT PROGRAM #35300 2018-04-10 00:00:00.000000
# PEP BOYS #795               2018-01-14 00:00:00.000000
# 7 ELEVEN SBT PROGRAM #13623 2018-07-08 00:00:00.000000
# 7 ELEVEN SBT PROGRAM #24483 2018-06-01 00:00:00.000000
# 7 ELEVEN SBT PROGRAM #24131 2018-03-30 12:00:00.000000
# 7 ELEVEN SBT PROGRAM #36897 2018-05-16 18:00:00.000000
# 7 ELEVEN SBT PROGRAM #11027 2018-05-08 14:24:00.000000
# 7 ELEVEN SBT PROGRAM #39622 2018-04-15 12:00:00.000000
# 7 ELEVEN SBT PROGRAM #36735 2018-07-02 00:00:00.000000
# 7 ELEVEN SBT PROGRAM #27211 2018-04-26 00:00:00.000000
# 7 ELEVEN SBT PROGRAM #33382 2018-05-01 19:12:00.000000
# 7 ELEVEN SBT PROGRAM #37461 2018-05-03 12:00:00.000000
# 7 ELEVEN SBT PROGRAM #12214 2018-05-27 00:00:00.000000
# 7 ELEVEN SBT PROGRAM #11510 2018-03-30 04:48:00.000000
# 7 ELEVEN SBT PROGRAM #11452 2018-06-20 00:00:00.000000
# 7 ELEVEN SBT PROGRAM #25290 2018-06-10 00:00:00.000000
# ...                                                ...
# SPEEDWAY #7652              2018-04-05 03:25:42.844800
# SPEEDWAY #7661              2017-12-23 03:25:42.844800
# SPEEDWAY #7697              2018-08-09 00:00:00.000000
# SPEEDWAY #7711              2018-03-01 10:17:08.534400
# SPEEDWAY #7790              2018-02-21 01:12:00.000000
# SPEEDWAY #7829              2018-03-12 00:00:00.000000
# SPEEDWAY #7838              2018-02-21 01:12:00.000000
# SPEEDWAY #7839              2018-02-21 01:12:00.000000
# SPEEDWAY #7843              2017-12-02 00:00:00.000000
# SPEEDWAY #7844              2018-04-21 09:36:00.000000
# SPEEDWAY #7849              2018-02-21 01:12:00.000000
# SPEEDWAY #7851              2018-02-21 01:12:00.000000
# SPEEDWAY #7877              2017-12-11 12:00:00.000000
# SPEEDWAY #7939              2017-12-09 00:00:00.000000
# SPEEDWAY #7993              2018-01-08 09:36:00.000000
# SPEEDWAY #8202              2017-11-24 16:48:00.000000
# SPEEDWAY #8211              2018-04-22 12:00:00.000000
# SPEEDWAY #8263              2018-04-25 00:00:00.000000
# SPEEDWAY #8309              2018-04-18 18:00:00.000000
# SPEEDWAY #8317              2017-11-09 20:34:17.155200
# SPEEDWAY #8534              2017-12-30 18:00:00.000000
# SPEEDWAY #8724              2018-04-19 12:00:00.000000
# SPEEDWAY #8848              2017-12-28 22:17:08.534400
# SPEEDWAY #8854              2018-01-15 04:14:07.094400
# SPEEDWAY #9326              2017-12-23 13:42:51.465600
# SPEEDWAY #9574              2018-01-14 16:56:28.204800
# STAPLES #1124               2018-02-21 01:12:00.000000
# STAPLES #154                2018-02-21 01:12:00.000000
# STAPLES #837                2018-02-21 01:12:00.000000
# STAPLES #953                2018-02-21 01:12:00.000000
#
#                                      period4_pred_date  agg_shrink_value
# address1
# 7 ELEVEN SBT PROGRAM #20722 2018-08-03 00:00:00.000000        -24.157236
# 7 ELEVEN SBT PROGRAM #34130 2018-05-12 06:51:25.689600        -21.625456
# 7 ELEVEN SBT PROGRAM #21888 2018-05-18 00:00:00.000000        -17.483446
# SPEEDWAY #7853              2018-08-24 00:00:00.000000        -15.256222
# RICH OIL #7785              2018-04-17 00:00:00.000000        -12.589092
# KWIK CHEK #37               2018-08-08 00:00:00.000000        -12.066893
# 7 ELEVEN SBT PROGRAM #24440 2018-05-26 00:00:00.000000        -11.887945
# 7 ELEVEN SBT PROGRAM #33847 2018-08-26 16:00:00.028800        -10.703013
# 7 ELEVEN SBT PROGRAM #37297 2018-07-08 00:00:00.000000         -9.277266
# 7 ELEVEN SBT PROGRAM #13619 2018-05-24 00:00:00.000000         -8.891583
# SPEEDWAY #6786              2018-07-29 00:00:00.000000         -8.645822
# 7 ELEVEN SBT PROGRAM #39347 2018-06-12 14:24:00.000000         -8.639104
# MILLER MART #84             2018-02-13 04:48:00.000000         -8.618509
# 7 ELEVEN SBT PROGRAM #29415 2018-06-20 04:48:00.000000         -8.374051
# 7 ELEVEN SBT PROGRAM #35300 2018-05-10 16:00:00.028800         -8.090240
# PEP BOYS #795               2018-02-02 16:00:00.028800         -7.469060
# 7 ELEVEN SBT PROGRAM #13623 2018-09-13 07:59:59.971200         -6.015262
# 7 ELEVEN SBT PROGRAM #24483 2018-07-21 00:00:00.000000         -5.984901
# 7 ELEVEN SBT PROGRAM #24131 2018-05-03 07:59:59.971200         -5.652457
# 7 ELEVEN SBT PROGRAM #36897 2018-07-07 00:00:00.000000         -5.593905
# 7 ELEVEN SBT PROGRAM #11027 2018-06-23 19:12:00.000000         -5.327217
# 7 ELEVEN SBT PROGRAM #39622 2018-05-19 16:00:00.028800         -5.317128
# 7 ELEVEN SBT PROGRAM #36735 2018-09-05 00:00:00.000000         -4.670044
# 7 ELEVEN SBT PROGRAM #27211 2018-06-01 00:00:00.000000         -4.648403
# 7 ELEVEN SBT PROGRAM #33382 2018-06-15 09:36:00.000000         -4.332522
# 7 ELEVEN SBT PROGRAM #37461 2018-06-12 00:00:00.000000         -4.299066
# 7 ELEVEN SBT PROGRAM #12214 2018-07-19 07:59:59.971200         -4.185915
# 7 ELEVEN SBT PROGRAM #11510 2018-04-27 14:24:00.000000         -4.022752
# 7 ELEVEN SBT PROGRAM #11452 2018-08-15 00:00:00.000000         -3.608044
# 7 ELEVEN SBT PROGRAM #25290 2018-08-08 00:00:00.000000         -3.607142
# ...                                                ...               ...
# SPEEDWAY #7652              2018-05-09 20:34:17.155200               NaN
# SPEEDWAY #7661              2018-01-18 20:34:17.155200               NaN
# SPEEDWAY #7697              2018-10-25 07:59:59.971200               NaN
# SPEEDWAY #7711              2018-03-31 13:42:51.465600               NaN
# SPEEDWAY #7790              2018-03-07 09:36:00.000000               NaN
# SPEEDWAY #7829              2018-04-20 07:59:59.971200               NaN
# SPEEDWAY #7838              2018-03-07 09:36:00.000000               NaN
# SPEEDWAY #7839              2018-03-07 09:36:00.000000               NaN
# SPEEDWAY #7843              2018-01-03 00:00:00.000000               NaN
# SPEEDWAY #7844              2018-06-08 04:48:00.000000               NaN
# SPEEDWAY #7849              2018-03-07 09:36:00.000000               NaN
# SPEEDWAY #7851              2018-03-07 09:36:00.000000               NaN
# SPEEDWAY #7877              2017-12-27 07:59:59.971200               NaN
# SPEEDWAY #7939              2017-12-24 16:00:00.028800               NaN
# SPEEDWAY #7993              2018-01-24 04:48:00.000000               NaN
# SPEEDWAY #8202              2017-12-12 14:24:00.000000               NaN
# SPEEDWAY #8211              2018-06-02 16:00:00.028800               NaN
# SPEEDWAY #8263              2018-06-13 00:00:00.000000               NaN
# SPEEDWAY #8309              2018-06-05 00:00:00.000000               NaN
# SPEEDWAY #8317              2017-11-29 03:25:42.844800               NaN
# SPEEDWAY #8534              2018-01-15 00:00:00.000000               NaN
# SPEEDWAY #8724              2018-05-30 07:59:59.971200               NaN
# SPEEDWAY #8848              2018-01-14 13:42:51.465600               NaN
# SPEEDWAY #8854              2018-01-30 05:38:49.401600               NaN
# SPEEDWAY #9326              2018-01-15 10:17:08.534400               NaN
# SPEEDWAY #9574              2018-01-29 22:35:17.606400               NaN
# STAPLES #1124               2018-03-07 09:36:00.000000               NaN
# STAPLES #154                2018-03-07 09:36:00.000000               NaN
# STAPLES #837                2018-03-07 09:36:00.000000               NaN
# STAPLES #953                2018-03-07 09:36:00.000000               NaN
#
# [11798 rows x 23 columns]

# %%
def flag(cust_table, mult_over_min=4, amount_over_min=100, and_or='and'):
    foo = cust_table[ cust_table.agg_shrink_value > 0 ] \
        .groupby(['zip_code', 'address1']).sum()[['agg_shrink_value']].reset_index()
    loc_agg = foo.columns.get_loc('agg_shrink_value')
    loc_add = foo.columns.get_loc('address1')
    for zip in foo.zip_code.unique():
        bar = foo[ foo.zip_code == zip]
        min_val = bar.agg_shrink_value.min()
        for _, row in bar.iterrows():
            shrink_val = row[loc_agg]
            val_times_over_min = shrink_val / min_val
            val_amount_over_min = shrink_val - min_val
            if and_or == 'or':
                if (val_times_over_min >= 4) | (val_amount_over_min >= amount_over_min):
                    print(row[loc_add], ' - ', val_times_over_min, ' - ', val_amount_over_min)
            else:
                if (val_times_over_min >= 4) & (val_amount_over_min >= amount_over_min):
                    print(row[loc_add], ' - ', val_times_over_min, ' - ', val_amount_over_min)

# %%
flag(agg_table)
# Out:
# SPEEDWAY #9222  -  18.971139489682994  -  301.78098176290996
# SPEEDWAY #9259  -  20.879168678965545  -  176.8891174768396
# SHEETZ - DSD #254  -  4.968134505932008  -  100.72889527247054
# SHEETZ - DSD #506  -  14.951684222837995  -  160.8866169066976
# SPEEDWAY #9699  -  5.740165296558122  -  104.22382458236171
# SPEEDWAY #9704  -  9.722493514292642  -  174.98352018581718
# SPEEDWAY #1231  -  7.645648759711311  -  103.78173212951
# SPEEDWAY #1401  -  6.900884291803062  -  117.83676746194635
# SPEEDWAY #9314  -  12.119105189120075  -  197.0779657844124
# SPEEDWAY #5401  -  7.286146284467112  -  133.7938983130113
# SPEEDWAY #2201  -  26.641186337999162  -  123.32673722225343
# SPEEDWAY #2371  -  11.967485081479891  -  206.45061792170648
# SPEEDWAY #4100  -  7.94594330935911  -  126.86573986732024
# SPEEDWAY #7382  -  26.05898249389875  -  118.05450975613438

# %% [markdown]
# ## Test other NNs

# %%
def keras_MLP(X_train, X_test, y_train):
    model = Sequential()
    model.add(Dense(16, input_dim=X_train.shape[1]))
    model.add(Activation('tanh'))
    model.add(Dropout(0.5))
#     model.add(Dense(64, init='uniform'))
#     model.add(Activation('tanh'))
    adam = Adam()
    model.compile(loss='mean_squared_error', optimizer=adam)
    model.fit(X_train, y_train, nb_epoch=20, batch_size=16)

# %%
keras_MLP(X_train[model_mask_cols], X_test, y_train)

# %%
X_train[model_mask_cols].shape

# %%
reg = Regressor()
