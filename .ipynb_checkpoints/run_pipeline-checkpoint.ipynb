# %%
import pandas as pd
from data_clean import DataClean
from add_public_data import PublicData
from create_lag import CreateLag
from cust_seg import CustSeg
from split import Split
from std_scale import StdScale
from pred_model import PredModel
from forcast import Forcast
from sklearn.neural_network import MLPRegressor

# %%
pd.set_option('max_columns',500)

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import warnings
warnings.filterwarnings('ignore')
# Out:
# <style>.container { width:100% !important; }</style>

# %%
df = pd.read_pickle('data/SRP/raw_subset_20k.pkl')

# %%
# middle 1
dc = DataClean(remove_nan_rows=True)
df_clean = dc.fit_transform(df)

# %%
df_clean.head()
# Out:
#         visit_date prev_visit_date prev_item_move_date ship_id  \
# 2061709 2017-09-27      2017-09-13          2017-09-06  118558
# 2084815 2017-09-28      2017-09-14          2017-09-14  123692
# 3448678 2018-01-09      2017-12-19          2017-12-19   99160
# 2413859 2017-10-19      2017-10-05          2017-10-05  133058
# 2022997 2017-09-25      2017-09-11          2017-09-11  119436
#
#                   address1 sales_rep_id  item_id old_item_id     item_UPC  \
# 2061709     SPEEDWAY #2325    100223113  2975455        5743   5254860398
# 2084815     SPEEDWAY #7105    100264113     6834        6834  35828694004
# 3448678  SHEETZ - DSD #234    100212113  2987433     2987433   8079841558
# 2413859     SPEEDWAY #6434    100008110  1023108     1023108  71941070001
# 2022997     SPEEDWAY #5241    100287114  2100131     2100131  60870716188
#
#         old_item_UPC                 item_description  qty_POG_limit  qty_n  \
# 2061709  60870758926          IGEAR COATED WORK GLOVE              4      2
# 2084815  35828694004      PILL-STACKER 2 EPHEDRA FREE              6      6
# 3448678   8079841558                   SR KARAOKE MIC              4      0
# 2413859  71941070001    5 HR-XSTRENGTH BERRY (718128)             60      4
# 2022997  60870716188  ELEC-4' MICRO CHARGE/SYNC CABLE             11      1
#
#          qty_f  qty_o  qty_d  qty_delivery  qty_sales  unit_price  \
# 2061709      0      0      0             0          2        4.99
# 2084815      0      0      0             0          2        0.87
# 3448678      4      0      0             0          0       17.99
# 2413859      0      0      0             0          4        1.74
# 2022997      0      0      0             0          0        6.53
#
#          qty_prev_end_inventory  qty_out  qty_start_inventory  \
# 2061709                     4.0        2                    2
# 2084815                     6.0        6                    0
# 3448678                     0.0        4                    0
# 2413859                    60.0        4                   56
# 2022997                    11.0        1                   10
#
#          qty_end_inventory  qty_inv_out  qty_ex_del  qty_shrink  \
# 2061709                  4          2.0         2.0         0.0
# 2084815                  6          6.0         6.0         4.0
# 3448678                  0          0.0         0.0         0.0
# 2413859                 60          4.0         4.0         0.0
# 2022997                 11          1.0         1.0         1.0
#
#          qty_shrink_out  qty_shrink_ex_del  sales_value  shrink_value  \
# 2061709               0                0.0         9.98          0.00
# 2084815               4                4.0         1.74          3.48
# 3448678               4                0.0         0.00          0.00
# 2413859               0                0.0         6.96          0.00
# 2022997               1                1.0         0.00          6.53
#
#          shrink_to_sales_value_pct  shrink_value_out  \
# 2061709                        0.0              7.98
# 2084815                      200.0              3.22
# 3448678                        0.0             71.96
# 2413859                        0.0              2.96
# 2022997                      653.0              6.53
#
#          shrink_to_sales_value_pct_out  shrink_value_ex_del  \
# 2061709                      79.959920                 0.00
# 2084815                     185.057471                 3.48
# 3448678                    7196.000000                 0.00
# 2413859                      42.528736                 0.00
# 2022997                     653.000000                 6.53
#
#          shrink_to_sales_value_pct_ex_del ship_list_pk sales_rep_id_2  \
# 2061709                               0.0       138671      100223113
# 2084815                             200.0       139284      100264113
# 3448678                               0.0       132637      100212113
# 2413859                               0.0       142567      100008110
# 2022997                             653.0       138130      100287114
#
#                      address2       city state list_header_id  \
# 2061709          635 TECUMSEH     DUNDEE    MI        3386280
# 2084815  5540 MURFREESBORO RD  LA VERGNE    TN        3386280
# 3448678  239 THREE SPRINGS DR    WEIRTON    WV        2634209
# 2413859    3270 VINELAND ROAD  KISSIMMEE    FL        3386280
# 2022997         711 S MAIN ST  ENGLEWOOD    OH        3386280
#
#              last_edit_date       creation_date  visit_date_int  \
# 2061709 2017-09-09 09:00:38 2016-08-23 07:37:37    1.506492e+09
# 2084815 2016-08-23 07:37:38 2016-08-23 07:37:37    1.506578e+09
# 3448678 2016-08-23 07:37:38 2016-08-23 07:37:37    1.515481e+09
# 2413859 2017-03-25 04:09:03 2016-08-23 07:37:37    1.508393e+09
# 2022997 2017-01-05 10:00:36 2016-08-23 07:37:37    1.506319e+09
#
#          prev_visit_date_int  prev_item_move_date_int  last_edit_date_int  \
# 2061709         1.505282e+09             1.504678e+09        1.504969e+09
# 2084815         1.505369e+09             1.505369e+09        1.471959e+09
# 3448678         1.513667e+09             1.513667e+09        1.471959e+09
# 2413859         1.507183e+09             1.507183e+09        1.490436e+09
# 2022997         1.505110e+09             1.505110e+09        1.483636e+09
#
#          creation_date_int  zip_code  qty_shrink_per_day  \
# 2061709       1.471959e+09     48131            0.000000
# 2084815       1.471959e+09     37086            0.285714
# 3448678       1.471959e+09     26062            0.000000
# 2413859       1.471959e+09     34746            0.000000
# 2022997       1.471959e+09     45322            0.071429
#
#          shrink_value_per_day  item_category_8  item_category_10  \
# 2061709              0.000000                0                 0
# 2084815              0.248571                0                 0
# 3448678              0.000000                0                 0
# 2413859              0.000000                0                 0
# 2022997              0.466429                0                 0
#
#          item_category_16  item_category_19  item_category_31  \
# 2061709                 0                 0                 0
# 2084815                 0                 0                 0
# 3448678                 1                 0                 0
# 2413859                 0                 0                 0
# 2022997                 1                 0                 0
#
#          item_category_38  item_category_41  item_category_43  \
# 2061709                 0                 0                 0
# 2084815                 0                 0                 0
# 3448678                 0                 0                 0
# 2413859                 0                 0                 0
# 2022997                 0                 0                 0
#
#          item_category_44  item_category_46  item_category_58  \
# 2061709                 0                 0                 1
# 2084815                 1                 0                 0
# 3448678                 0                 0                 0
# 2413859                 1                 0                 0
# 2022997                 0                 0                 0
#
#          item_category_62  item_category_77  item_category_79  \
# 2061709                 0                 0                 0
# 2084815                 0                 0                 0
# 3448678                 0                 0                 0
# 2413859                 0                 0                 0
# 2022997                 0                 0                 0
#
#          item_category_90  customer_id_2139  customer_id_1635139  \
# 2061709                 0                 0                    0
# 2084815                 0                 0                    0
# 3448678                 0                 0                    0
# 2413859                 0                 0                    0
# 2022997                 0                 0                    0
#
#          customer_id_1903139  customer_id_2331150  customer_id_2741156  \
# 2061709                    0                    1                    0
# 2084815                    0                    1                    0
# 3448678                    1                    0                    0
# 2413859                    0                    1                    0
# 2022997                    0                    1                    0
#
#          customer_id_2773156  customer_id_2782156  customer_id_2956160  \
# 2061709                    0                    0                    0
# 2084815                    0                    0                    0
# 3448678                    0                    0                    0
# 2413859                    0                    0                    0
# 2022997                    0                    0                    0
#
#          customer_id_2977160  customer_id_3083182  customer_id_3088198  \
# 2061709                    0                    0                    0
# 2084815                    0                    0                    0
# 3448678                    0                    0                    0
# 2413859                    0                    0                    0
# 2022997                    0                    0                    0
#
#          customer_id_3088201  customer_id_3089336  customer_id_3093327  \
# 2061709                    0                    0                    0
# 2084815                    0                    0                    0
# 3448678                    0                    0                    0
# 2413859                    0                    0                    0
# 2022997                    0                    0                    0
#
#          customer_id_3093329 item_category customer_id
# 2061709                    0            58     2331150
# 2084815                    0            44     2331150
# 3448678                    0            16     1903139
# 2413859                    0            44     2331150
# 2022997                    0            16     2331150

# %%
# middle 2
pub = PublicData(include_crime=False, remove_nan_rows=True)
df_public_cust = pub.fit_transform(df_clean)

# %%
# left 1
cl_cat = CreateLag(lag_periods=2, col_filters=['address1', 'item_category'], 
                   date_col='visit_date', lag_vars=['qty_shrink_per_day', 'shrink_value_per_day'], 
                   col_name_suf='_by_cat', remove_nan_rows=True)
df_lag_cat = cl_cat.fit_transform(df_clean)

# %%
# middle 3
cs = CustSeg(clusters=4)
cust_table = cs.fit_transform(df_public_cust)

# %%
# right 1
cl_store = CreateLag(lag_periods=2, col_filters=['address1'], 
                   date_col='visit_date', lag_vars=['qty_shrink_per_day', 'shrink_value_per_day'], 
                   col_name_suf='_by_store', remove_nan_rows=True)
df_lag_store = cl_store.fit_transform(df_clean)

# %% [markdown]
# ### Public for Lag

# %%
# left 2
df_public_cat = pub.fit_transform(df_lag_cat)

# %%
# right 2
df_public_store = pub.fit_transform(df_lag_store)

# %% [markdown]
# ### Split

# %%
non_feature_cols = ['shrink_value', 'shrink_to_sales_value_pct', 'shrink_value_out', 'shrink_to_sales_value_pct_out',
               'shrink_value_ex_del', 'shrink_to_sales_value_pct_ex_del', 'qty_inv_out', 'qty_shrink',
               'qty_shrink_ex_del', 'qty_shrink_out', 'qty_end_inventory', 'qty_f', 'qty_out', 'qty_ex_del',
               'qty_n', 'qty_delivery', 'qty_o', 'qty_d', 'qty_shrink_per_day', 'shrink_value_per_day']

# %%
# left 3
spl_cat = Split(non_feature_cols, target_col='shrink_value_per_day', split_by_time=False)
spl_cat.fit(df_public_cat, cust_table)
X, y, X_train_cat, X_test_cat, y_train_cat, y_test_cat \
= spl_cat.transform(df_public_cat, cust_table)

# %%
# right 3
split_date = pd.to_datetime('12/15/2017')
spl_store = Split(non_feature_cols, target_col='shrink_value_per_day', split_by_time=True, date_col='visit_date', split_date=split_date)
spl_store.fit(df_public_store, cust_table)
X, y, X_train_store, X_test_store, y_train_store, y_test_store \
= spl_store.transform(df_public_store, cust_table)

# %% [markdown]
# ### Std and Scale

# %%
ss = StdScale(std=True, scale=True)

# %%
# left 4
X_train_cat_ss = ss.fit_transform(X_train_cat)
X_test_cat_ss = ss.fit_transform(X_test_cat)

# %%
# right 4
X_ss = ss.fit_transform(X)
X_train_store_ss = ss.fit_transform(X_train_store)
X_test_store_ss = ss.fit_transform(X_test_store)

# %% [markdown]
# ### Model

# %%
model = MLPRegressor()
params = {'hidden_layer_sizes': [(300,), (100,), (50,50), (50,50,50)], 'learning_rate_init': [0.01, 0.001, 0.0001], 
          'activation': ['identity', 'logistic', 'tanh', 'relu'], 'solver': ['adam'],  'max_iter': [200]}
params_basic = {'hidden_layer_sizes': [(10)], 'learning_rate_init': [0.01], 
          'activation': ['relu'], 'solver': ['adam'],  'max_iter': [10]}

# %%
# left 5
pm = PredModel(model, params_basic)
pm.fit(X_train_cat_ss, y_train_cat)
# Out:
# cluster:  1
#
# cluster:  2
#
# cluster:  3
#
# cluster:  4

# %%
# left 5 (continued)
preds = pm.predict(X_test_cat_ss)

# %%
X_ss.head()
# Out:
#          FD_ratio  LAPOP1_10   POP2010           address1  \
# 2061709 -1.057444  -0.900063 -0.499550     SPEEDWAY #2325
# 2084815  0.385362  -0.432952 -0.378367     SPEEDWAY #7105
# 3448678  2.435387  -0.945373 -0.632527  SHEETZ - DSD #234
# 2413859  1.599775  -0.126472 -0.371703     SPEEDWAY #6434
# 2022997  0.396961   0.240800 -0.079693     SPEEDWAY #5241
#
#                      address2       city cluster       creation_date  \
# 2061709          635 TECUMSEH     DUNDEE       2 2016-08-23 07:37:37
# 2084815  5540 MURFREESBORO RD  LA VERGNE       2 2016-08-23 07:37:37
# 3448678  239 THREE SPRINGS DR    WEIRTON       2 2016-08-23 07:37:37
# 2413859    3270 VINELAND ROAD  KISSIMMEE       2 2016-08-23 07:37:37
# 2022997         711 S MAIN ST  ENGLEWOOD       2 2016-08-23 07:37:37
#
#          creation_date_int customer_id  customer_id_1635139  \
# 2061709                0.0     2331150                    0
# 2084815                0.0     2331150                    0
# 3448678                0.0     1903139                    0
# 2413859                0.0     2331150                    0
# 2022997                0.0     2331150                    0
#
#          customer_id_1903139  customer_id_2139  customer_id_2331150  \
# 2061709                    0                 0                    1
# 2084815                    0                 0                    1
# 3448678                    1                 0                    0
# 2413859                    0                 0                    1
# 2022997                    0                 0                    1
#
#          customer_id_2741156  customer_id_2773156  customer_id_2782156  \
# 2061709                    0                    0                    0
# 2084815                    0                    0                    0
# 3448678                    0                    0                    0
# 2413859                    0                    0                    0
# 2022997                    0                    0                    0
#
#          customer_id_2956160  customer_id_2977160  customer_id_3083182  \
# 2061709                    0                    0                    0
# 2084815                    0                    0                    0
# 3448678                    0                    0                    0
# 2413859                    0                    0                    0
# 2022997                    0                    0                    0
#
#          customer_id_3088198  customer_id_3088201  customer_id_3089336  \
# 2061709                    0                    0                    0
# 2084815                    0                    0                    0
# 3448678                    0                    0                    0
# 2413859                    0                    0                    0
# 2022997                    0                    0                    0
#
#          customer_id_3093327  customer_id_3093329  dens_sq_mile     item_UPC  \
# 2061709                    0                    0     -0.632461   5254860398
# 2084815                    0                    0     -0.240532  35828694004
# 3448678                    0                    0     -0.394805   8079841558
# 2413859                    0                    0     -0.382938  71941070001
# 2022997                    0                    0     -0.287897  60870716188
#
#         item_category  item_category_10  item_category_16  item_category_19  \
# 2061709            58                 0                 0                 0
# 2084815            44                 0                 0                 0
# 3448678            16                 0                 1                 0
# 2413859            44                 0                 0                 0
# 2022997            16                 0                 1                 0
#
#          item_category_31  item_category_38  item_category_41  \
# 2061709                 0                 0                 0
# 2084815                 0                 0                 0
# 3448678                 0                 0                 0
# 2413859                 0                 0                 0
# 2022997                 0                 0                 0
#
#          item_category_43  item_category_44  item_category_46  \
# 2061709                 0                 0                 0
# 2084815                 0                 1                 0
# 3448678                 0                 0                 0
# 2413859                 0                 1                 0
# 2022997                 0                 0                 0
#
#          item_category_58  item_category_62  item_category_77  \
# 2061709                 1                 0                 0
# 2084815                 0                 0                 0
# 3448678                 0                 0                 0
# 2413859                 0                 0                 0
# 2022997                 0                 0                 0
#
#          item_category_79  item_category_8  item_category_90  \
# 2061709                 0                0                 0
# 2084815                 0                0                 0
# 3448678                 0                0                 0
# 2413859                 0                0                 0
# 2022997                 0                0                 0
#
#                         item_description  item_id      last_edit_date  \
# 2061709          IGEAR COATED WORK GLOVE  2975455 2017-09-09 09:00:38
# 2084815      PILL-STACKER 2 EPHEDRA FREE     6834 2016-08-23 07:37:38
# 3448678                   SR KARAOKE MIC  2987433 2016-08-23 07:37:38
# 2413859    5 HR-XSTRENGTH BERRY (718128)  1023108 2017-03-25 04:09:03
# 2022997  ELEC-4' MICRO CHARGE/SYNC CABLE  2100131 2017-01-05 10:00:36
#
#          last_edit_date_int list_header_id old_item_UPC old_item_id  \
# 2061709            0.758466        3386280  60870758926        5743
# 2084815            0.000000        3386280  35828694004        6834
# 3448678            0.000000        2634209   8079841558     2987433
# 2413859            0.424547        3386280  71941070001     1023108
# 2022997            0.268283        3386280  60870716188     2100131
#
#         prev_item_move_date  prev_item_move_date_int prev_visit_date  \
# 2061709          2017-09-06                 0.751766      2017-09-13
# 2084815          2017-09-14                 0.767648      2017-09-14
# 3448678          2017-12-19                 0.958311      2017-12-19
# 2413859          2017-10-05                 0.809337      2017-10-05
# 2022997          2017-09-11                 0.761692      2017-09-11
#
#          prev_visit_date_int  qty_POG_limit  qty_prev_end_inventory  \
# 2061709             0.765663      -0.456586               -0.439972
# 2084815             0.767648      -0.365683               -0.345012
# 3448678             0.958311      -0.456586               -0.629892
# 2413859             0.809337       2.088700                2.218917
# 2022997             0.761692      -0.138425               -0.107611
#
#          qty_sales  qty_shrink_per_day_lag1_by_store  \
# 2061709  -0.099474                         -0.272843
# 2084815  -0.099474                         -0.049505
# 3448678  -0.393432                         -0.064394
# 2413859   0.194484                         -0.272843
# 2022997  -0.393432                         -0.272843
#
#          qty_shrink_per_day_lag2_by_store  qty_start_inventory sales_rep_id  \
# 2061709                         -0.244481            -0.458466    100223113
# 2084815                          0.002631            -0.587359    100264113
# 3448678                          0.216795            -0.587359    100212113
# 2413859                         -0.244481             3.021648    100008110
# 2022997                         -0.491593             0.057107    100287114
#
#         sales_rep_id_2  sales_value ship_id ship_list_pk  \
# 2061709      100223113     0.189919  118558       138671
# 2084815      100264113    -0.400378  123692       139284
# 3448678      100212113    -0.525028   99160       132637
# 2413859      100008110    -0.026427  133058       142567
# 2022997      100287114    -0.525028  119436       138130
#
#          shrink_value_per_day_lag1_by_store  \
# 2061709                           -0.340509
# 2084815                            0.151183
# 3448678                            0.559320
# 2413859                           -0.340509
# 2022997                           -0.340509
#
#          shrink_value_per_day_lag2_by_store state  unemp_rate  unit_price  \
# 2061709                           -0.347740    MI    1.330335   -0.262751
# 2084815                            0.119558    TN   -0.187780   -1.298924
# 3448678                            0.190864    WV    0.419466    3.006727
# 2413859                           -0.347740    FL    0.115843   -1.080120
# 2022997                           -0.915174    OH   -0.491403    0.124557
#
#         visit_date  visit_date_int  zip_code
# 2061709 2017-09-27        0.793456  0.151939
# 2084815 2017-09-28        0.795441 -0.393793
# 3448678 2018-01-09        1.000000 -0.938488
# 2413859 2017-10-19        0.837130 -0.509412
# 2022997 2017-09-25        0.789485  0.013147

# %%
# right 5
forc_cols = ['FD_ratio', 'LAPOP1_10', 'POP2010', 'dens_sq_mile', 'unemp_rate', 'qty_POG_limit', 'unit_price', 
             'shrink_value_per_day_lag1_by_store', 'shrink_value_per_day_lag2_by_store' ]
for col in X_ss.columns:
    if 'customer_id' in col:
        forc_cols.append(col)
fc = Forcast(model, params, forc_cols, num_periods=4)
fc.fit(X_ss, y)
# Out:
# cluster:  1
#
# cluster:  2
#
# cluster:  3
#
# cluster:  4
# -------------------------------------------------------------------
# TypeError                         Traceback (most recent call last)
# <ipython-input-60-00a0a1ae936b> in <module>()
#       6         forc_cols.append(col)
#       7 fc = Forcast(model, params, forc_cols, num_periods=4)
# ----> 8 fc.fit(X_ss, y)
#
# ~/Dropbox/Galvanize/DSI/Capstone/Mashey/forcast.py in fit(self, X, y)
#      70         self.y = y
#      71         self.grid()
# ---> 72         self._create_models()
#      73         for index, model in enumerate(self.model_list):
#      74             fit_clust_mask = self.X.cluster == str(index)
#
# ~/Dropbox/Galvanize/DSI/Capstone/Mashey/forcast.py in _create_models(self)
#      26     def _create_models(self):
#      27         self.model_list = []
# ---> 28         for i in len(self.X.cluster.unique()):
#      29             foo_model = self.model
#      30             foo_model.set_params(self.best_params_list[i])
#
# TypeError: 'int' object is not iterable

# %%
# right 5 (continued)
forc_cust_table = fc.forcast(cust_table)
